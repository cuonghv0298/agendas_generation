# %%
from src.utils import utils
import json
import os 
import pandas as pd

# %%
questions_list = [
  "What are the main objectives and focus areas of the meeting?",
  "Who are the participants, and what are their roles?",
  "What are the latest updates on assigned tasks and significant developments?",
  "What previous action items are still pending, and what challenges were faced?",
  "What major topics need to be discussed, and what insights have been shared?",
  "What challenges are currently being faced, and what solutions have been proposed?",
  "What key decisions need to be made, and what are their implications?",
  "What are the next steps, assigned tasks, and deadlines?",
  "What follow-up actions and plans are required for the next meeting?"
]
len(questions_list)
# Out:
# 9

# %% [markdown]
# # Create collection

# %%
from src.utils.embedding import VectorDB
file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
vectordb = VectorDB(model_config)
collection_id = 'LangChain_agd_7bb158e64c93bea491df09894psd'
collection_id, text_key = vectordb.create_collection(collection_id)
print(collection_id)
# Out:
# Weaviate Client connect with ANONYMOUS
# ------VectorDB client: <weaviate.client.WeaviateClient object at 0x7fe2b810dcc0>
# LangChain_agd_7bb158e64c93bea491df09894psd

# %% [markdown]
# # Create Data for EMBEDDING

# %%
root = "/datadrive/CuongHV/project/DATA/AMI_MS"
files = os.listdir(root)
data = []
for file in files:
    print(f"process {file}")
    # load json file
    path = f'{root}/{file}'
    with open(path, encoding="utf8") as f:
        jsondict = json.load(f)
    # Transcripts
    transcripts_cleaned = utils.clean_text(jsondict['transcript'])

    # Summary
    summary_cleaned = utils.clean_text(jsondict['summary'])

    # Shared doc
        # Extract text from txt, ppt, and doc
    try:
        txt = []
        for x in jsondict['shared-doc']['txt']:
            filename = x['filename']
            content = x['content']
            content_clean = utils.clean_text(content)
            txt_item = {
                'filename': filename,
                'content': content_clean,
            }
            txt.append(txt_item)
    except Exception as e:
        print(f"Error processing txt: {e}")
        txt = []
    try:
        ppt = []
        for x in jsondict['shared-doc']['ppt']:
            filename = x['filename']
            string = ['\n'.join(v) for k,v in x['content'].items()]
            content = '\n'.join(string)
            content_clean = utils.clean_text(content)
            ppt_item = {
                'filename': filename,
                'content': content_clean,
            }
            ppt.append(ppt_item)
    except Exception as e:
        print(f"Error processing ppt: {e}")
        ppt_content = []
    try:
        doc = []
        for x in jsondict['shared-doc']['doc']:
            filename = x['filename']
            content = x['content']
            content_clean = utils.clean_text(content)
            doc_item = {
                'filename': filename,
                'content': content_clean,
            }
            doc.append(doc_item)
    except Exception as e:
        print(f"Error processing doc: {e}")
        doc_content = []

    # Save as cleaned json
    cleaned_jsondict = {
        "transcript": transcripts_cleaned,
        "summary": summary_cleaned,
        "actions": jsondict['actions'],
        "decisions": jsondict['decisions'],
        "problems": jsondict['problems'],
        "shared-doc": {
            "txt": txt,
            "ppt": ppt,
            "doc": doc
        },
    }
    with open(f"/datadrive/CuongHV/project/DATA/AMI_MS_RAG_Cleaned/{file}", "w", encoding="utf8") as f:
        json.dump(cleaned_jsondict, f, ensure_ascii=False, indent=4)
    print(f'{file} done')
# Out:
# process ES2004d.json
# ES2004d.json done
# process ES2008b.json
# ES2008b.json done
# process IS1000b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1000b.json done
# process IS1004d.json
# IS1004d.json done
# process IS1008a.json
# IS1008a.json done
# process ES2015b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2015b.json done
# process IS1004a.json
# IS1004a.json done
# process TS3011b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3011b.json done
# process ES2015d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2015d.json done
# process IS1005b.json
# IS1005b.json done
# process ES2008c.json
# ES2008c.json done
# process TS3003a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3003a.json done
# process ES2013d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2013d.json done
# process ES2008d.json
# ES2008d.json done
# process ES2013c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2013c.json done
# process ES2015c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2015c.json done
# process IS1006d.json
# IS1006d.json done
# process IS1006c.json
# IS1006c.json done
# process IS1005a.json
# IS1005a.json done
# process ES2006d.json
# ES2006d.json done
# process ES2004b.json
# ES2004b.json done
# process TS3008a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3008a.json done
# process ES2009d.json
# ES2009d.json done
# process IS1005c.json
# IS1005c.json done
# process TS3003b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3003b.json done
# process TS3010b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3010b.json done
# process TS3012a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3012a.json done
# process ES2005a.json
# ES2005a.json done
# process TS3008c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3008c.json done
# process ES2013b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2013b.json done
# process ES2006b.json
# ES2006b.json done
# process IS1001c.json
# IS1001c.json done
# process ES2003a.json
# ES2003a.json done
# process IS1001d.json
# IS1001d.json done
# process IS1001a.json
# IS1001a.json done
# process ES2002b.json
# ES2002b.json done
# process ES2011b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2011b.json done
# process ES2016c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2016c.json done
# process ES2004c.json
# ES2004c.json done
# process ES2014b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2014b.json done
# process ES2012b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2012b.json done
# process ES2002a.json
# ES2002a.json done
# process ES2003c.json
# ES2003c.json done
# process ES2008a.json
# ES2008a.json done
# process ES2014d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2014d.json done
# process ES2012a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2012a.json done
# process ES2006c.json
# ES2006c.json done
# process ES2007d.json
# ES2007d.json done
# process ES2014a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2014a.json done
# process IS1009d.json
# IS1009d.json done
# process ES2013a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2013a.json done
# process IS1009b.json
# IS1009b.json done
# process TS3006b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3006b.json done
# process IS1000c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1000c.json done
# process ES2005d.json
# ES2005d.json done
# process IS1006b.json
# IS1006b.json done
# process TS3011c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3011c.json done
# process TS3007a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3007a.json done
# process ES2009b.json
# ES2009b.json done
# process ES2010d.json
# ES2010d.json done
# process IS1002b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1002b.json done
# process ES2002d.json
# ES2002d.json done
# process IS1001b.json
# IS1001b.json done
# process ES2016a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2016a.json done
# process IS1003b.json
# IS1003b.json done
# process ES2012c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2012c.json done
# process TS3008d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3008d.json done
# process ES2007b.json
# ES2007b.json done
# process ES2012d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2012d.json done
# process IS1004c.json
# IS1004c.json done
# process IS1000d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1000d.json done
# process IS1003d.json
# IS1003d.json done
# process TS3006a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3006a.json done
# process TS3011a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3011a.json done
# process ES2002c.json
# ES2002c.json done
# process IS1000a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1000a.json done
# process IS1002c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1002c.json done
# process IS1008b.json
# IS1008b.json done
# process ES2005b.json
# ES2005b.json done
# process ES2009a.json
# ES2009a.json done
# process IS1003a.json
# IS1003a.json done
# process ES2010b.json
# ES2010b.json done
# process ES2011c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2011c.json done
# process TS3009a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3009a.json done
# process ES2016b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2016b.json done
# process TS3008b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3008b.json done
# process IS1009a.json
# IS1009a.json done
# process IS1002d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# IS1002d.json done
# process ES2007c.json
# ES2007c.json done
# process TS3012b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3012b.json done
# process IS1007b.json
# IS1007b.json done
# process IS1006a.json
# IS1006a.json done
# process ES2007a.json
# ES2007a.json done
# process ES2015a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2015a.json done
# process ES2016d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2016d.json done
# process IS1008d.json
# IS1008d.json done
# process ES2010c.json
# ES2010c.json done
# process TS3005c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3005c.json done
# process ES2011a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2011a.json done
# process IS1007c.json
# IS1007c.json done
# process ES2005c.json
# ES2005c.json done
# process IS1008c.json
# IS1008c.json done
# process TS3005a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3005a.json done
# process TS3005b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3005b.json done
# process IS1007d.json
# IS1007d.json done
# process TS3009b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3009b.json done
# process IS1007a.json
# IS1007a.json done
# process ES2006a.json
# ES2006a.json done
# process TS3006c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3006c.json done
# process TS3009d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3009d.json done
# process ES2011d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2011d.json done
# process ES2009c.json
# ES2009c.json done
# process TS3005d.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3005d.json done
# process ES2014c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# ES2014c.json done
# process ES2004a.json
# ES2004a.json done
# process TS3010a.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3010a.json done
# process ES2003b.json
# ES2003b.json done
# process ES2010a.json
# ES2010a.json done
# process TS3010c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3010c.json done
# process IS1009c.json
# IS1009c.json done
# process IS1003c.json
# IS1003c.json done
# process TS3007b.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3007b.json done
# process ES2003d.json
# ES2003d.json done
# process IS1004b.json
# IS1004b.json done
# process TS3009c.json
# Error processing txt: 'NoneType' object is not iterable
# Error processing ppt: 'NoneType' object is not iterable
# Error processing doc: 'NoneType' object is not iterable
# TS3009c.json done

# %% [markdown]
# # EMBEDDING

# %%
from src.utils.embedding import VectorDB
file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
vectordb = VectorDB(model_config)

# %%
file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
vectordb = VectorDB(model_config)
# Out:
# Weaviate Client connect with ANONYMOUS
# ------VectorDB client: <weaviate.client.WeaviateClient object at 0x7fe3213ee740>

# %%
df_shared_docs = utils.load_data_with_shared_doc_path()
df_shared_docs['file'].values[:4]
# Out:
# array(['ES2004d.json', 'ES2008b.json', 'IS1004d.json', 'IS1008a.json'],
#       dtype=object)

# %%
root = '/datadrive/CuongHV/project/DATA/AMI_MS_RAG_Cleaned'
sample_jsondict = utils.extract_data_from_file(file='ES2004d.json', root=root)
sample_jsondict['shared-doc']
# Out:
# {'txt': [{'filename': 'ES2004docs.ES2004scen.Summaries.P1Sum1.txt',
#    'content': 'Received: from [139.222.1.2] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 11:48:31 +0000\nMessage-ID: <001b01c4fe1c$f97d62e0$0201de8b@participant1>\nFrom: "participant1" <participant1@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe19$Blat.v2.2.2$6084975a@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 11:49:45 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_0018_01C4FE1C.F88D84A0"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_0018_01C4FE1C.F88D84A0\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after e\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant1@ami=20\nSent: Wednesday, January 19, 2005 11:24 AM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\nThis was the first meeting of our team, a new project was introduced - =\nthe ddesign, manufacture and distribution of a new remote control.=20\nWe talked for the first time and became better aquainted with =\neachother through an extra task - drawing pictures of animals and each =\ntalkiing about them.\nWe concluded the meeting with a brief discussion about our project and =\nwhat we want to get out of it; key features we think are important and =\ndesign concerns. We also discussed our budget and how that could affect =\nour plans for the product.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n1) We decided upon a \'universal control\' one handset for all your =\nt.v. and video equiptment.*\n2) It is important that the product is accessable to a wide age-range =\nof consumers. *\n=20\n3) We decided that it was important to reflect the company\'s image in =\nour product, \'We put the fasion in electronics\' *\n=20\n4) Our budget will affect the specific design of the product, we want =\nit to look trendy but not expensive to produce - silver plastic etc.\n5) We want the control to look uncluttered and undaunting to the =\nconsumer. *\n6) A flip open design was discussed, which would reduce the size of =\nthe control.\n7) An electronic panel should be inside for further features such as =\nteletext, programming and sound functions.\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\n=20\n1) Our design aim, being trendy and upmarket might clash with our =\nbudget - this is to be discussed at a later date. *\n2) We don\'t want to alienate \'older\' consumers with the use of too =\nmuch technology in our product.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P1Sum2.txt',
#    'content': 'Received: from [139.222.1.2] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 12:50:48 +0000\nMessage-ID: <004301c4fe25$ace65dc0$0201de8b@participant1>\nFrom: "participant1" <participant1@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe23$Blat.v2.2.2$da93f3ba@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 12:52:02 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_0040_01C4FE25.AC0A55A0"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_0040_01C4FE25.AC0A55A0\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after e\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant1@ami=20\nSent: Wednesday, January 19, 2005 12:39 PM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\no\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\nThis was our second meeting, where we tried to make as many decisions =\nas possible as to the design of our product.\nEach of the members of the group presented their individual findings =\nas a power point presentation, and there was general discussion at the =\nend of the sessions.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n1) The shape should be unique to us - shell design was mentioned\n2) alarm to signify where the remote is if it gets lost\n3) rechargable batteries, with a port that it can be placed in, to act =\nas the \'hub\'\n4) To aim our design at young proffesionals, trendy, fasionable\n5) possibility of touch buttons\n6) No programming function, just \'video plus\' instead.\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\nDesign hasn\'t been agreed on yet\n=20\nwant to make the handset trendy, but not too small - repetetive =\nstrain injury*\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\nUI designer will look further into the shape and buttons of our =\ncontrol\nID will look into touch buttons and rechargable battery packs\nMarketing will focus on insruction manual and looking into what people =\nexpect from their control.\n------=_NextPart_000_0040_01C4FE25.AC0A55A0\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short ques ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P1Sum3.txt',
#    'content': 'Received: from [139.222.1.2] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 15:27:51 +0000\nMessage-ID: <007701c4fe3b$9d845ec0$0201de8b@participant1>\nFrom: "participant1" <participant1@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe36$Blat.v2.2.2$b629baf6@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 15:29:05 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_0074_01C4FE3B.9C714110"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_0074_01C4FE3B.9C714110\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after e\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant1@ami=20\nSent: Wednesday, January 19, 2005 2:54 PM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\n=20\nThis was our third meeting to date. The team feel comfortable with =\neachother, and don\'t hesitate to mention if they are unhappy with a =\nparticular point. The meeting was very usefull in clearing up all of the =\nideas we\'d had floating about. We made a lot of important decisions.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n1)We will use a kinetic charger for our product\n2) We will use the standard chip on the market - TA11835\n3) We want to incorporate a standby function\n4)The case material will be rubber\n5)The buttons will be a combination of LCD and rubber according to the =\ndesign\n6)We will use bright, funky designs for the casing\n7)we will try to incorporate voice recognition software into our =\ndesign\n8) the rubber buttons we will use will be anti Repetitive Strain =\nInjury\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\n=20\nwe are worried about the costs involved with our design\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\n------=_NextPart_000_0074_01C4FE3B.9C714110\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TITLE>\n<META http-equiv=3DContent-Type content=3D"text/html; =\ncharset=3Diso-8859-1">\n<META content=3DWord.Document name= ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P1Sum4.txt',
#    'content': 'From: "participant1" <participant1@ami>\nTo: <HeadOfDept@ami>\nSubject: Re: Please summarise the last meeting.\nDate: 19 January 2005 16:34\nFor the documentation of the design project, you and all of your colleages are asked to fill out a short questionnaire after e\n----- Original Message ----- \nFrom: HeadOfDept@ami \nTo: participant1@ami \nSent: Wednesday, January 19, 2005 4:16 PM\nSubject: Please summarise the last meeting.\nDear Colleague,\n\nWould you be so kind to report to me on the past meeting? Please hit the reply button and fill in the questions below, then click send. Please keep in mind that your notes are part of the project documentation - among other things, they will be used by myself and other staff to stay informed about the state of the project. It is therefore essential that your notes - though kept short - are of high quality. In particular:\n\na.. Do not use any abbreviations. \nb.. Write notes that are understandable for somebody who was not present during the meeting \n\nThe head of your department\n\n\n[ABSTRACT]   Write one paragraph of coherent text to summarize the meeting as a whole from your role\'s perspective.\n\n\n\n\n\nThis was our concluding meeting for our project design. Everyone gave feedback, and there was a general sense of achievement. we felt we had done well and fulfilled all of the specifications.\n\n\n\n[DECISIONS]   Name all decisions that were made during the meeting. Mark those decisions that you consider of high importance for your role with a *. Write fragmented notes.\n\n\n1)      There will be a central core, which is neutral - white/light blue\n2)      The LCD screen is set in to the handset so that it closes fully\n3)      Voice recognition should be used in order to find the remote if it lost\n4)      It will use IR transmission and 2 separate PCB\'s\n5)      The touch screen will be black and white to save on costs\n6)      The lower half of the design will have the very basic buttons on it; volume, power, programme etc.\n7)      We had to change the design to a flat design from double curved. We would make up for this in the shape of the foam cover.\n8)      We also had to abandon the voice recognition software because of our budget, however we still recommend that this is pursued.\n\n\n\n\n\n\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred during the meeting. Mark those that you consider of high importance for your role with a *. Write fragmented notes.\n\n\n\nWe could have done with more control over the budget, and the financial information at the beginning, when we were designing.\n\n\n\n\n\n[ACTIONS]  Name the next steps that each member will take until the next meeting. Write fragmented notes.\n\x00'},
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P2Sum1.txt',
#    'content': 'Received: from [139.222.1.3] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 11:34:51 +0000\nMessage-ID: <001e01c4fe1a$fbedffa0$0301de8b@participant2>\nFrom: "participant2" <participant2@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe19$Blat.v2.2.2$6086f9b4@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 11:35:30 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_001B_01C4FE1A.FB05C280"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_001B_01C4FE1A.FB05C280\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after e\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant2@ami=20\nSent: Wednesday, January 19, 2005 11:24 AM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\nThe process of the first meeting was to get aquainted with all the =\nother members of the team. Since this was just the first meeting not =\nmany decisions were\nmade, i feel that everyone needed to get used to their role within the =\ncompany. The team discussed the overall problem and several ideas about =\nthe project.\nThe meeting was mainly centralised round people passing ideas around, =\nthough not coming to any solid decisions I think.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\nTo make the TV remote easy to use for anyone=20\nPredominately made of plastic\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\nThe pen fell apart, though since we had finished using it this was =\nonly of minor conciquence\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\nUI Design - Looking into LCD Displays\nInd. Design - Working Design\nMarket - Will the consumer like it?\nProject Man. - Looking into general costing of project\n------=_NextPart_000_001B_01C4FE1A.FB05C280\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TITLE>\n<META http-equiv=3DContent-Type content=3D"text/html; =\ncharset=3Diso-8859-1">\n<META content=3DWord.Document name=3DProgId>\n<META content=3D"MSHTML 6.00.2900.2523" name=3DGENERATO ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P2Sum2.txt',
#    'content': 'Received: from [139.222.1.3] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 12:45:52 +0000\nMessage-ID: <003001c4fe24$e828c400$0301de8b@participant2>\nFrom: "participant2" <participant2@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe23$Blat.v2.2.2$da9b1ac8@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 12:46:32 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_002D_01C4FE24.E74E4280"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_002D_01C4FE24.E74E4280\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after e\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant2@ami=20\nSent: Wednesday, January 19, 2005 12:39 PM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\nWe decided on the design of the project internally and externally, =\nalso we looked at the target audiences that we will be appealing to.\nMost of the meeting was concerened with external design issues and =\nmarketing aims.=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\nDesign Element Internal*\nDesign Elements External*\nTarget Audience Aims\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\nNone really, though I feel the team may be getting too focused on =\nminor points rather than tacaling the problem in hand.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\nRechargeable Docking station\nBatteries\nWhistle...\n------=_NextPart_000_002D_01C4FE24.E74E4280\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TITLE>\n<META http-equiv=3DContent-Type content=3D"text/html; =\ncharset=3Diso-8859-1">\n<META content=3DWord.Document name=3DProgId>\n<META content=3D"MSHTML 6.00.2900.2523" name=3DGENERATOR>\n<META content=3D"Microsoft Word 10" name=3DOriginator><LINK=20\nhref=3D"SummaryFramework_files/filelist.xml" rel=3DFile-List><!--[if gte =\nmso 9]><xml>\n<o:DocumentProperties>\n<o:Author>Thomas Kleinbauer</o:Author>\n<o:LastAuthor>AMI</o:LastAuthor>\n<o:Revision>4</o:Revision ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P2Sum3.txt',
#    'content': 'Received: from [139.222.1.3] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 15:15:12 +0000\nMessage-ID: <005001c4fe39$c4bb59a0$0301de8b@participant2>\nFrom: "participant2" <participant2@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe36$Blat.v2.2.2$b6380912@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 15:15:52 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_004A_01C4FE39.C3DF5180"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_004A_01C4FE39.C3DF5180\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after e\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant2@ami=20\nSent: Wednesday, January 19, 2005 2:54 PM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\nThe meeting went well, and lots of points were raised and desisions =\nmad particularly those regarding the physical design of the phone.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\nKinetic Battery combo*\nLCD Touch screen*\nAnti-RSI Rubberised buttons=20\nRubber Facias\nMain body plastic\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\nThe main problems that were solved this meeting were those related to =\nthe power source and those of the contol interface.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\nFinalised Design\n------=_NextPart_000_004A_01C4FE39.C3DF5180\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TITLE>\n<META http-equiv=3DContent-Type content=3D"text/html; =\ncharset=3Diso-8859-1">\n<META content=3DWord.Document name=3DProgId>\n<META content=3D"MSHTML 6.00.2900.2523" name=3DGENERATOR>\n<META content=3D"Microsoft Word 10" name=3DOriginator><LINK=20\nhref=3D"SummaryFramework_files/filelist.xml" rel=3DFile-List><!--[if gte =\nmso 9]><xml>\n<o:DocumentProperties>\n<o:Author>Thomas Kleinbauer</o:Author>\n<o:LastAuthor>AMI</o:LastAuthor>\n<o:Revision>4</o:Revision>\n<o:TotalTime>2</o:TotalTime>\n<o:LastPrinted>2004-10-21T15:56:00Z</o:LastPrinted>\n< ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P2Sum4.txt',
#    'content': 'From: "participant2" <participant2@ami>\nTo: <HeadOfDept@ami>\nSubject: Re: Please summarise the last meeting.\nDate: 19 January 2005 16:33\nFor the documentation of the design project, you and all of your colleages are asked to fill out a short questionnaire after e\n----- Original Message ----- \nFrom: HeadOfDept@ami \nTo: participant2@ami \nSent: Wednesday, January 19, 2005 4:16 PM\nSubject: Please summarise the last meeting.\nDear Colleague,\n\nWould you be so kind to report to me on the past meeting? Please hit the reply button and fill in the questions below, then click send. Please keep in mind that your notes are part of the project documentation - among other things, they will be used by myself and other staff to stay informed about the state of the project. It is therefore essential that your notes - though kept short - are of high quality. In particular:\n\na.. Do not use any abbreviations. \nb.. Write notes that are understandable for somebody who was not present during the meeting \n\nThe head of your department\n\n\n[ABSTRACT]   Write one paragraph of coherent text to summarize the meeting as a whole from your role\'s perspective.\nThe final meeting was mainly concerned with showing the first prototype of the new remote, i feel our ideas were well accepted.\nThere was a final discussion about how we felt the team worked and it was decided that we did it better as a team,\nthough working apart between meetings allowed us to compose separate solutions to the problem in hand. \n\n\n\n\n\n[DECISIONS]   Name all decisions that were made during the meeting. Mark those decisions that you consider of high importance for your role with a *. Write fragmented notes.\nChanged from double curved to single curved\nScrapped Voice recognition* \nFinished the design!* \n\n\n\n\n\n\n\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred during the meeting. Mark those that you consider of high importance for your role with a *. Write fragmented notes.\nSince our product was running over budget we had to make the desision to cut the voice recognition system that we had included in the prototype.*\nDid we combat the problem of RSI?\n\n\n\n\n\n\n\n\n[ACTIONS]  Name the next steps that each member will take until the next meeting. Write fragmented notes.\nSend completed design to Head of Department.\nStart Production!!\n\x00'},
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P3Sum1.txt',
#    'content': 'Received: from [139.222.1.4] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 11:42:36 +0000\nMessage-ID: <002a01c4fe1c$2051aee0$0401de8b@participant3>\nFrom: "participant3" <participant3@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe19$Blat.v2.2.2$607d704c@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 11:43:41 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_0027_01C4FE1C.1F604A00"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_0027_01C4FE1C.1F604A00\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after eMinutes of =\nthe meeting\nAgenda: Development of new Television remote control\nParticipants: Project Manager, Industrial Designer, user Interface =\nDesigner and Marketing Expert\nDuration: 30 minutes\n=20\nThe meeting started with the Project Manager defining the agenda, the =\nconcept (trendy, original and user friendly) and financial guidelines =\n(Price Euro 20, Production cost: Euro 12.5) for the product. To break =\nthe ice, all members drew their favourite animal. The discussion started =\nwith brainstorming on the main features. Some of the suggestions were =\nmulti-utility concept (i.e. the same remote control for TV, Video and =\naudio devices), a user friendly browsing menu (similar to the mobile =\nphone menu) and a flip top design (to add more features and yet keep it =\ncompact). In certain ideas, such as flip-top design, concerns were =\nexpressed on the financial costs.=20\nOverall, the meeting was very interactive with all members expressing =\ntheir opinion in a constructive and democratic way.\n=20\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant3@ami=20\nSent: Wednesday, January 19, 2005 11:24 AM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\n------=_NextPart_000_0027_01C4FE1C.1F604A00\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of t ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P3Sum2.txt',
#    'content': 'Received: from [139.222.1.4] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 12:49:25 +0000\nMessage-ID: <005001c4fe25$75ccd620$0401de8b@participant3>\nFrom: "participant3" <participant3@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe23$Blat.v2.2.2$da9fdf7c@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 12:50:30 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_004D_01C4FE25.74EF4760"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_004D_01C4FE25.74EF4760\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after eMinutes of =\nMeeting 2:\nA brief presentation by all members on their finding and suggestions\n1. Industrial Designer -=20\nFindings - the interface between TV and remote control\n=20\n2. User Interface Designer -=20\nFinding - People want simple and user friendly design. Not too =\ncomplicated\nSuggestions - A flip top design with main features on the top. A =\ndifferent/trendy design\n=20\n3. Marketing expert -\nFindings - People find the current remote controls ugly, mostly only 10% =\nof the buttons used, misplacing the device, demand for LCD or speech =\nrecognition\n=20\nProject manager coordinated to put all these ideas into a final design. =\nThe outcome:\nRemote control for TV only\nIncorporate the Corporate Logo\nRechargable batteries\nUser friendly manual\nFlip top design\nA different and interesting look - e,.g: a shell, conch etc\nSoft buttons or touch screen\nA detection device to trace it, if lost\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant3@ami=20\nSent: Wednesday, January 19, 2005 12:39 PM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\n------=_NextPart_000_004D_01C4FE25.74EF4760\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TIT ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P3Sum3.txt',
#    'content': 'Received: from [139.222.1.4] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 15:12:58 +0000\nMessage-ID: <00b801c4fe39$838b9350$0401de8b@participant3>\nFrom: "participant3" <participant3@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe36$Blat.v2.2.2$b6904014@messenger>\nSubject: Re: Please summarise the last meeting\nDate: Wed, 19 Jan 2005 15:14:02 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_00B5_01C4FE39.828C72D0"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_00B5_01C4FE39.828C72D0\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after eMeeting =\nagenda - conceptual Design\nAfter exchanging the views from all departments, the design was decided =\nas:\n1. Trendy - Vibrant colors. inpiration from fruits\n2. Satandardised componentTA11385 chip\n3. Plastic body with rubber casing. rubber casing can be changed\n4. Top bord - Black and white LCD display. Bottom board - Standard =\nRubber buttons\n5. corporate logo\n6. kinetic batteries\n7. Device to locate if lost\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant3@ami=20\nSent: Wednesday, January 19, 2005 2:54 PM\nSubject: Please summarise the last meeting\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\n------=_NextPart_000_00B5_01C4FE39.828C72D0\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TITLE>\n<META http-equiv=3DContent-Type content=3D"text/html; =\ncharset=3Diso-8859-1">\n<META content=3DWord.Document name=3DProgId>\n<META content=3D"MSHTML 6.00.2900.2523" name=3DGENERATOR>\n<META content=3D"Microsoft Word 10" name=3DOriginator><LINK=20\nhref=3D"SummaryFramework_files/filelist.xml" rel=3DFile-List><!--[if gte =\nmso 9]><xml>\n<o:DocumentProperties>\n<o:Author>Thomas Kleinbauer</o:Author>\n<o:LastAuthor>AMI</o:LastAuthor>\n<o:Revision>4</o:Revision>\n<o:TotalTime>2</o:TotalTi ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P3Sum4.txt',
#    'content': 'Received: from [139.222.1.4] by messenger\n(ArGoSoft Mail Server Freeware, Version 1.8 (1.8.6.4)); Wed, 19 Jan 2005 16:24:20 +0000\nMessage-ID: <013301c4fe43$7be16710$0401de8b@participant3>\nFrom: "participant3" <participant3@ami>\nTo: <HeadOfDept@ami>\nReferences: <01c4fe42$Blat.v2.2.2$2b2fbee4@messenger>\nSubject: Re: Please summarise the last meeting.\nDate: Wed, 19 Jan 2005 16:25:24 -0000\nMIME-Version: 1.0\nContent-Type: multipart/alternative;\n\tboundary="----=_NextPart_000_0130_01C4FE43.7ACFD000"\nX-Priority: 3\nX-MSMail-Priority: Normal\nX-Mailer: Microsoft Outlook Express 6.00.2900.2180\nX-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180\nThis is a multi-part message in MIME format.\n------=_NextPart_000_0130_01C4FE43.7ACFD000\nContent-Type: text/plain;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\nFor the documentation of the design project, you and all of your =\ncolleages are asked to fill out a short questionnaire after eMinutes: =\nMeeting 4\nAgenda - Final Design Phase\n1. Meeting started with the industrial design and User interface design =\nteam presenting the prototype with description of internal, external and =\ninterface features.=20\n2. The marketing expert then presented the evaluation criteria. The =\naverage criteria was approx 2 (True =3D1 and False =3D7).\n3. The cost analysis was done to estimate the total cost of production. =\nA few features such as voice recognition had to be foregone due to the =\nbudget constraints.\nUnanimously, the final design was approved with an evaluation of the =\nentire project - team work, creativity, etc.=20\n----- Original Message -----=20\nFrom: HeadOfDept@ami=20\nTo: participant3@ami=20\nSent: Wednesday, January 19, 2005 4:16 PM\nSubject: Please summarise the last meeting.\nDear Colleague,\n=20\nWould you be so kind to report to me on the past meeting? Please hit =\nthe reply button and fill in the questions below, then click send. =\nPlease keep in mind that your notes are part of the project =\ndocumentation - among other things, they will be used by myself and =\nother staff to stay informed about the state of the project. It is =\ntherefore essential that your notes - though kept short - are of high =\nquality. In particular:\n=20\na.. Do not use any abbreviations.=20\nb.. Write notes that are understandable for somebody who was not =\npresent during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role\'s perspective.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[ACTIONS]  Name the next steps that each member will take until the =\nnext meeting. Write fragmented notes.\n------=_NextPart_000_0130_01C4FE43.7ACFD000\nContent-Type: text/html;\n\tcharset="iso-8859-1"\nContent-Transfer-Encoding: quoted-printable\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<HTML xmlns=3D"http://www.w3.org/TR/REC-html40" xmlns:o =3D=20\n"urn:schemas-microsoft-com:office:office" xmlns:w =3D=20\n"urn:schemas-microsoft-com:office:word"><HEAD><TITLE>For the =\ndocumentation of the design project, you and all of your colleages are =\nasked to fill out a short questionnaire after e</TITLE>\n<META http-equiv=3DContent-Type content=3D"text/html; =\ncharset=3Diso-8859-1">\n<META content=3DWord.Document name=3DProgId>\n<META content=3D"MSHTML 6.00.2900.2523" name=3DGENERATOR>\n<META content=3D"Microsoft Word 10" name=3DOriginator><LINK=20\nhref=3D"SummaryFramework ...
#   {'filename': 'ES2004docs.ES2004scen.Summaries.P4Sum1.txt',
# ...
#   {'filename': 'ES2004docs.ES2004scen.participant4hBcQuestionnairePost.doc',
#    'content': 'Questionnaire after the meetings cycle \nName: Dale Anderson\n\nBackground information \n(Please place an ‘*’ next to your answers)\n\n1. Do you feel that the objectives for today’s meetings were generally attained? \nNever\nHardly ever \nSometimes\nMost of the times* \nAlways\n\n2. Do you feel that the time for today’s meetings was generally well-spent? \nNever\nHardly ever \nSometimes\nMost of the times *\nAlways\n\n3. Did you generally enjoy participating in today’s meetings? \nNever\nHardly ever \nSometimes\nMost of the times *\nAlways\n\n4. Which of the following did you make use of before the meetings to prepare for the meetings (beside the instructions from your personal coach)? \nMinutes of the previous meeting(s)\nRelated documentation and information (e-mail, internet, project folder)*\nAgenda\nPersonal recollection*\nPersonal notes of the previous meeting(s)*\nMake personal notes*\nShared notes from the previous meeting(s) (whiteboard)\nPresentations from previous meeting(s)\nPrepare a presentation*\nE-mail other participants\nOther:  \n\n5. Which of the following did you make use of during the meetings?\nMinutes of the previous meeting(s)*\nRelated documentation and information (e-mail, internet, project folder)* \nAgenda\nPersonal recollection*\nPersonal notes of the previous meeting(s) *\nMake personal notes *\nShared notes from the previous meeting(s) (whiteboard) \nMake/discuss shared notes (whiteboard) *\nPresentations from the previous meeting(s) \nGive/discuss a presentation *\nOther:  \n\n6. Which of the following did you make use of after the meetings (to process the results)? \nMinutes of the previous meeting(s)\nRelated documentation and information (e-mail, internet, project folder) *\nAgenda\nPersonal recollection*\nPersonal notes of the previous meeting(s)* \nMake personal notes* \nShared notes from the previous meeting(s) (whiteboard) \nPresentations from the previous meeting(s) \nE-mail other participants \nOther:  \n\n7. What types of information did you include in your personal notes? \nDecisions taken*\nThings to do*\nThings you wanted to tell others\nReminders*\nReference materials (names, phone numbers, webpages)\n"Doodles" (absent-minded scribbles) \nOther:  \nSummaries of notes from personal  coach and from web  pages\n8. What types of information did you regret, in retrospect, not having \nincluded into your personal notes? \nDecisions taken\nThings to do\nThings you wanted to tell others\nReminders\nReference materials (names, phone numbers, webpages)\n"Doodles" (absent-minded scribbles) \nOther:  \n\n9. If a ‘smart meeting room’ could automatically create multi-media recordings of the meeting (‘smart minutes’), what information would you like these to include? Please indicate the top-5 of your preferences. \nSpeech (audio) *\nTranscribed speech (text) *\nOther audio (non-speech sounds), for example ....\nPictures*\nVideo – overview* \nVideo – close-ups of participants \nUsed documents and presentations *\nAgenda*\nYour personal notes \nShared notes \nInformation on participants *\nOther:  on screen summaries [text] of decisions taken & actions to be taken\nOther:  \nOther:  \n\n10. If ‘smart minutes’ were available, how would you like to search for specific information within the minutes? Please indicate the top-5 of your preferences \nBy topics*\nBy agenda items *\nBy participants/speakers*\nBy quotes of participants \nBy gestures of participants\nBy facial expressions of participants\nBy emotions of participants\nBy movements of participants\nBy discussions between participants\nBy decisions taken*\nBy arguments for decisions\nBy means used during the meeting (presentations, notes etc.)\nBy things to do*\nBy specific points in time\nBy specific locations in the meeting room\nOther:  \nOther:  \nOther:  \n\n11. If a ‘smart meeting room’ could automatically create multi-media recordings of the meeting (‘smart minutes’), what information would you like these to include?  \nBr ...
#   {'filename': 'ES2004docs.ES2004scen.participant4hBcQuestionnairePre.doc',
#    'content': 'Questionnaire before the meeting cycle \n(if completing electronically please place an ‘*’ next to your answers)\nName:_____*Dale Anderson_____________________________________\n\nBackground information \n\n1. What is your gender?\nMale\nFemale*\n\n2. What is your age?\n__*38______ years\n\n3. What is your current education type or highest earned degree?\nPhD\nMaster\'s Degree*\nFirst Degree\nA-level/High School (US)\nOther:  \n4. What is your current profession / study?\nHealth & Fitness Practitioner/Consultant\n\n\nTechnology experience\n\n5. How often do you use a computer?\nNever\nMonthly\nWeekly\nDaily*\n\n6. How often do you use the Internet for browsing webpages?\nNever\nMonthly\nWeekly\nDaily - less than 1 hour*\nDaily - 1 to 3 hours\nDaily - more than 3 hours\n\n7. How often do you use the Internet for email?\nNever\nMonthly\nWeekly\nDaily - less than 1 hour*\nDaily - 1 to 3 hours\nDaily - more than 3 hours\n\n8. How often do you use the Internet for chatting?\nNever*\nMonthly\nWeekly\nDaily - less than 1 hour\nDaily - 1 to 3 hours\nDaily - more than 3 hours\n9. How often do you search for multi-media content (audio (e.g. music) or video (e.g. movies)) on the computer?\nNever*\nMonthly\nWeekly\nDaily - less than 1 hour\nDaily - 1 to 3 hours\nDaily - more than 3 hours\n\n10. Which of the following devices do you own or use regularly?\nLaptop*\nMobile Phone*\nPDA\nMP3-player\nNone of the above\n\n\nMeeting experience\n\n11. How often do you participate in meetings?\nNever\nMonthly*\nWeekly\nDaily - once\nDaily - more than once\n12. What is approximately the typical size of your meetings?\n___4-6_____ number of participants\n\n13. What is approximately the typical length of your meetings?\n___45-60_____ minutes\n\n14. How would you characterize your typical meetings (e.g. subject matter, objective, atmosphere)?  Mainly work-focused [health & fitness issues, public health, safety etc], objectives may be related to programme format, budgeting issues, staffing, programme success, etc., atmosphere is semi-formal i.e. focused but relaxed.\n\n\n15. What role(s) do you typically perform in meetings?\nChairman\nDraw up the minutes\nParticipant*\nOther:  \n\n16. Do you feel that the objectives for your meetings are generally attained?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n17. Do you feel that the time for your meetings is generally well-spent?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n18. Do you generally like to participate in your meetings?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n19. Which of the following do you make use of before a meeting (to prepare for the meeting)?\nMinutes of the previous meeting(s)*\nRelated documents*\nAgenda*\nPersonal recollection*\nContact other participants\nPersonal notes of the previous meeting(s)*\nMeans to prepare a presentation\nPictures of previous meeting(s)\nAudio recording of previous meeting(s)\nVideo recording of previous meeting(s)\nConsult external information sources (e.g. internet)*\nContact external people (face-to-face, e-mail, telephone)\nOther:  \n\n20. Which of the following do you make use of during a typical meeting?\nMinutes of the previous meeting(s)*\nUse and annotate related documents*\nAgenda*\nPersonal recollection*\nMake personal notes*\nMake/discuss shared notes (e.g. on blackboard, whiteboard, flip-over)*\nGive/discuss a presentation*\nMake pictures\nMake audio recording\nMake video recording\nConsult external information resources (e.g., internet)\nContact external people (e-mail, telephone)\nAudio conferencing tools\nVideo conferencing tools\nOther:  \n\n21. Which of the following do you typically make use of after a meeting (to process the results)?\nMinutes of the previous meeting(s)*\nRelated documents *\nAgenda*\nPersonal recollection*\nContact other participants* \nPersonal notes of the previous meeting(s) *\nMeans to prepare a presentation \nPictures of previous meeting(s) \nAudio  ...
#   {'filename': 'ES2004docs.ES2004scen.ProjectDocuments.Minutes.for-meting-4approx-time-40min.doc',
#    'content': 'Minutes for meting 4\t\t\t\t\tapprox time 40min\nThe industrial designer and user interface designer began once the minutes had been reviewed; they presented their prototype design to the rest of the group and highlighted key features;\n\t\n\tThere will be a central core, which is neutral – white/light blue\n\tThe LCD screen is set in to the handset so that it closes fully\n\tVoice recognition should be used in order to find the remote if it lost\n\tIt will use IR transmission and 2 separate PCB’s\n\tThe touch screen will be black and white to save on costs\n\tThe lower half of the design will have the very basic buttons on it; volume, power, programme etc.\n\t\n\t\n\tThe evaluation was given by the marketing expert;\n\t\n\tWe scored the highest on incorporating current fashion and ease of use.\n\tOur lowest was that the design minimises RSI, however we considered our attention to this area to be acceptable.\n\t\n\tWe then looked at the financial feasibility of the project;\n\t\n\tWe had to change the design to a flat design from double curved. We would make up for this in the shape of the foam cover.\n\tWe also had to abandon the voice recognition software because of our budget, however we still recommend that this is pursued.'},
#   {'filename': 'ES2004docs.ES2004scen.ProjectDocuments.Minutes.from-meeting-number-1.doc',
#    'content': "Minutes from meeting number 1:\t\t\tmeeting duration 25min\nAll of the members of the team are introduced to each other.\nThe main aims for the product were discussed; trendy, user friendly & original\nThe group then took turns at drawing their favourite animal and summarising what characteristics they associated that animal with.\nThe selling price and budget were discussed, highlighting that we might have dissonance between the budget and our ‘ideal’ design.\nOur product will sell at 25 euros and our production is 12.50 euros.\nWe then discussed our first thoughts and ideas;\nWe decided upon a 'universal control' one handset for all your TV. and video equipment.\nWe decided that It is important that\xa0the product\xa0be accessible to a wide age-range of consumers.\nWe decided that it was important to reflect the company's image in our product, 'We put the fashion in electronics'.\nOur budget\xa0will affect the specific design of the product, we want it to look trendy but not expensive to produce - silver plastic etc.\nWe want the control to look uncluttered and un-daunting to the consumer.\nA flip open design was discussed, which would reduce the size of the control.\nAn electronic panel should be inside for further features such as teletext, programming and sound functions."},
#   {'filename': 'ES2004docs.ES2004scen.ProjectDocuments.Minutes.from-meeting-number-2.doc',
#    'content': 'Minutes from meeting number 2\t\t\t      approx time meeting took; 40min\nFunctional design meeting;\nSession opened with the minutes from last meeting, then each member of the team presents their latest work.\nIndustry designer talked about the different options available for batteries, AA, AAA, rechargeable.\nIf we used rechargeable, there would be a port in which it sat overnight etc. This would also have an option on it, which can alert the consumer to the control’s whereabouts if it is lost.\nIt was said that in general the cost of general components should be quite low.\nOur product needs to be different, as everything else in the market is much the same.\nThe User Interface designer talked about having soft buttons and bright colours to try and fit with what is in greatest demand.\nThe Marketing Expert raised a few issues; that people rarely use all of the buttons available to them anyway, so by reducing what we put on our control we are meeting the customer’s needs and reducing costs for ourselves.\nSize was also mentioned, in reference to how easily lost controls are. If it is too small, it would make this problem worse.\nSpeech recognition software was mentioned, as more research is being carried out in this field, it is a real option for our consideration.\nIt was decided that there would not be the usual video programming options, instead we will use ‘video plus’, which will be an advertising point.\nWe have decided that our target audience is the ‘Young professional’.\n\t\n\tOur brief changed; \n\twe are not to incorporate teletext into our design,\n\tIt is not to be an all-encompassing control, just TV and video,\n\tOur corporate image is to be heavily incorporated into the design'},
#   {'filename': 'ES2004docs.ES2004scen.ProjectDocuments.Minutes.of-Meeting-2.doc',
#    'content': 'Minutes of Meeting 2:\nA brief presentation by all members on their finding and suggestions\n1. Industrial Designer – \nFindings - the interface between TV and remote control\n2. User Interface Designer – \nFinding – People want simple and user friendly design. Not too complicated\nSuggestions – A flip top design with main features on the top. A different/trendy design\n3. Marketing expert –\nFindings – People find the current remote controls ugly, mostly only 10% of the buttons used, misplacing the device, demand for LCD or speech recognition\nProject manager coordinated to put all these ideas into a final design. The outcome:\nRemote control for TV only\nIncorporate the Corporate Logo\nRechargable batteries\nUser friendly manual\nFlip top design\nA different and interesting look – e,.g: a shell, conch etc\nSoft buttons or touch screen\nA detection device to trace it, if lost'},
#   {'filename': 'ES2004docs.ES2004scen.ProjectDocuments.Minutes.of-the-meeting.doc',
#    'content': 'Minutes of the meeting\nAgenda: Development of new Television remote control\nParticipants: Project Manager, Industrial Designer, user Interface Designer and Marketing Expert\nDuration: 30 minutes\nThe meeting started with the Project Manager defining the agenda, the concept (trendy, original and user friendly) and financial guidelines (Price Euro 20, Production cost: Euro 12.5) for the product. To break the ice, all members drew their favourite animal. The discussion started with brainstorming on the main features. Some of the suggestions were multi-utility concept (i.e. the same remote control for TV, Video and audio devices), a user friendly browsing menu (similar to the mobile phone menu) and a flip top design (to add more features and yet keep it compact). In certain ideas, such as flip-top design, concerns were expressed on the financial costs. \nOverall, the meeting was very interactive with all members expressing their opinion in a constructive and democratic way.'}]}

# %%
# Embedding and create a tracking file 
df_shared_docs = utils.load_data_with_shared_doc_path()
root = '/datadrive/CuongHV/project/DATA/AMI_MS_RAG_Cleaned'
data = []
for file in df_shared_docs['file'].values:
    print(file)
    collection_id, tenant_id = vectordb.create_tenant()
    data.append({
        'file': file,
        'tenant_id' : tenant_id,
    })
    sample_jsondict = utils.extract_data_from_file(file=file, root=root)
    # Embedding shared-docs
    for type, list_doc in sample_jsondict['shared-doc'].items():
        for x in list_doc:
            filename = x['filename']
            content = x['content']
            index, tenant_name, text_key, documents = vectordb.import_data_to_db(
                meta_data={'filename':filename}, 
                page_content=content,
                index_name=collection_id,
                tenant_name=tenant_id,
            )
# Out:
# ES2004d.json
# ES2008b.json
# IS1004d.json
# IS1008a.json
# IS1004a.json
# IS1005b.json
# ES2008c.json
# ES2008d.json
# IS1006d.json
# IS1006c.json
# IS1005a.json
# ES2006d.json
# ES2004b.json
# ES2009d.json
# IS1005c.json
# ES2005a.json
# ES2006b.json
# IS1001c.json
# ES2003a.json
# IS1001d.json
# IS1001a.json
# ES2002b.json
# ES2004c.json
# ES2002a.json
# ES2003c.json
# ES2008a.json
# ES2006c.json
# ES2007d.json
# IS1009d.json
# IS1009b.json
# ES2005d.json
# IS1006b.json
# ES2009b.json
# ES2010d.json
# ES2002d.json
# IS1001b.json
# IS1003b.json
# ES2007b.json
# IS1004c.json
# IS1003d.json
# ES2002c.json
# IS1008b.json
# ES2005b.json
# ES2009a.json
# IS1003a.json
# ES2010b.json
# IS1009a.json
# ES2007c.json
# IS1007b.json
# IS1006a.json
# ES2007a.json
# IS1008d.json
# ES2010c.json
# IS1007c.json
# ES2005c.json
# IS1008c.json
# IS1007d.json
# IS1007a.json
# ES2006a.json
# ES2009c.json
# ES2004a.json
# ES2003b.json
# ES2010a.json
# IS1009c.json
# IS1003c.json
# ES2003d.json
# IS1004b.json

# %%
data
# Out:
# [{'file': 'ES2004d.json',
#   'tenant_id': 'deploy_mind_81d33437db5d446ab045abac31d33c3b'},
#  {'file': 'ES2008b.json',
#   'tenant_id': 'deploy_mind_3ea93cd23e3842cc917060e649e8985b'},
#  {'file': 'IS1004d.json',
#   'tenant_id': 'deploy_mind_09280add1a10419c8919f5dd44f370d3'},
#  {'file': 'IS1008a.json',
#   'tenant_id': 'deploy_mind_8d5bd42fd4d54281ae71dba89cf81719'},
#  {'file': 'IS1004a.json',
#   'tenant_id': 'deploy_mind_a77940965a4c4faaae895ee479b43a5c'},
#  {'file': 'IS1005b.json',
#   'tenant_id': 'deploy_mind_7d96a11ac37c475386d6f92376405757'},
#  {'file': 'ES2008c.json',
#   'tenant_id': 'deploy_mind_5acd076cdfa1423eaa7c12d10b2bb57e'},
#  {'file': 'ES2008d.json',
#   'tenant_id': 'deploy_mind_252aa7441aae44cf82627066c3dcea4c'},
#  {'file': 'IS1006d.json',
#   'tenant_id': 'deploy_mind_017d7960aac74e198b57424574b202c2'},
#  {'file': 'IS1006c.json',
#   'tenant_id': 'deploy_mind_6fe34b555a0a4c4b9a265bd1611b7c65'},
#  {'file': 'IS1005a.json',
#   'tenant_id': 'deploy_mind_101b06c616e9460f8f709501d79bcc64'},
#  {'file': 'ES2006d.json',
#   'tenant_id': 'deploy_mind_e23b4b7e698a4dd68ea174313508595e'},
#  {'file': 'ES2004b.json',
#   'tenant_id': 'deploy_mind_d5c7f60a1403441e97843aeeb48c339a'},
#  {'file': 'ES2009d.json',
#   'tenant_id': 'deploy_mind_2b54e13fa6684283abde676173c6cffa'},
#  {'file': 'IS1005c.json',
#   'tenant_id': 'deploy_mind_d7378a78f95a4c93bba07976a3a73a20'},
#  {'file': 'ES2005a.json',
#   'tenant_id': 'deploy_mind_25b75e8f36414ba586c61c96e6d4674e'},
#  {'file': 'ES2006b.json',
#   'tenant_id': 'deploy_mind_b41c526f459b45b8945877be0757a690'},
#  {'file': 'IS1001c.json',
#   'tenant_id': 'deploy_mind_e3604fcf541c41ad96a9c0d095afc28a'},
#  {'file': 'ES2003a.json',
#   'tenant_id': 'deploy_mind_d7523ee2f00d4cffbd6966943509d53c'},
#  {'file': 'IS1001d.json',
#   'tenant_id': 'deploy_mind_707f690f44cd4466b814919f809cfc0f'},
#  {'file': 'IS1001a.json',
#   'tenant_id': 'deploy_mind_4b7b86649c6e40988d2210b76c823f5c'},
#  {'file': 'ES2002b.json',
#   'tenant_id': 'deploy_mind_7dbaf66183b64f06b05ace5013e81c53'},
#  {'file': 'ES2004c.json',
#   'tenant_id': 'deploy_mind_4911a96b94db474798bc31a008783f6c'},
#  {'file': 'ES2002a.json',
#   'tenant_id': 'deploy_mind_ac92523b886b49f9ae4aa75020c6b714'},
#  {'file': 'ES2003c.json',
#   'tenant_id': 'deploy_mind_ecd4935374844a3d9462d81fa85fdd75'},
#  {'file': 'ES2008a.json',
#   'tenant_id': 'deploy_mind_21aa50d5ba6d43fca0a0f0459f926d77'},
#  {'file': 'ES2006c.json',
#   'tenant_id': 'deploy_mind_d9d2307e9db44b7b978e819a4422e57c'},
#  {'file': 'ES2007d.json',
#   'tenant_id': 'deploy_mind_7e345007ab0b4475937eb3d6a65f4e69'},
#  {'file': 'IS1009d.json',
#   'tenant_id': 'deploy_mind_5f2a46ddf51241aab9cf918ca3b41e5e'},
#  {'file': 'IS1009b.json',
#   'tenant_id': 'deploy_mind_624f209e25824ccfaea094cb297b3fbd'},
#  {'file': 'ES2005d.json',
#   'tenant_id': 'deploy_mind_59d0daaffe3d49f3913ad21936c65e6a'},
#  {'file': 'IS1006b.json',
#   'tenant_id': 'deploy_mind_5fa9e954213f420091f0a0505c66f9b9'},
#  {'file': 'ES2009b.json',
#   'tenant_id': 'deploy_mind_faa088b03ee048ca94ed082f97dc0297'},
#  {'file': 'ES2010d.json',
#   'tenant_id': 'deploy_mind_6d303a7c8ba84a0cadfd74a22c352207'},
#  {'file': 'ES2002d.json',
#   'tenant_id': 'deploy_mind_a5c9141e86fc4197b7971cecdbfe5b5b'},
#  {'file': 'IS1001b.json',
#   'tenant_id': 'deploy_mind_e558f2ff71184adc876015eb0dbd4290'},
#  {'file': 'IS1003b.json',
#   'tenant_id': 'deploy_mind_55e064a24a7a4c24a74c4c230c9c8092'},
#  {'file': 'ES2007b.json',
#   'tenant_id': 'deploy_mind_15aa689f7fa3465b850b0ad5f6821dc9'},
#  {'file': 'IS1004c.json',
#   'tenant_id': 'deploy_mind_5e2180d0395840c991911bc1e78e097f'},
#  {'file': 'IS1003d.json',
#   'tenant_id': 'deploy_mind_9c5e044c795e48ba859bac8636912ab6'},
#  {'file': 'ES2002c.json',
#   'tenant_id': 'deploy_mind_7f3d390fdf5d40cbabc9132e61815bc0'},
#  {'file': 'IS1008b.json',
#   'tenant_id': 'deploy_mind_63e3152e6752498f8228d5c3ad4b5520'},
#  {'file': 'ES2005b.json',
#   'tenant_id': 'deploy_mind_6697b18312c4457a9fe30797e38e6391'},
#  {'file': 'ES2009a.json',
#   'tenant_id': 'deploy_mind_8013034c06d546a28f65b7cf6e4dc8d4'},
#  {'file': 'IS1003a.json',
#   'tenant_id': 'deploy_mind_a804ca27c2434280a248fa2daf08aae1'},
#  {'file': 'ES2010b.json',
#   'tenant_id': 'deploy_mind_37ba00d818a043118bbfdd053b644a01'},
#  {'file': 'IS1009a.json',
#   'tenant_id': 'deploy_mind_296cc7ce57b34a398ef4e8188839fd40'},
#  {'file': 'ES2007c.json',
#   'tenant_id': 'deploy_mind_97958584f16441d280df54d40c295f3e'},
#  {'file': 'IS1007b.json',
#   'tenant_id': 'deploy_mind_a55287a968124974952e2aae07e9855b'},
#  {'file': 'IS1006a.json',
#   'tenant_id': 'deploy_mind_cdde0283fbb040dcbbc7a43e898d0efa'},
#  {'file': 'ES2007a.json',
#   'tenant_id': 'deploy_mind_02f1d3f1701c4c1698bbab8245b8b389'},
#  {'file': 'IS1008d.json',
#   'tenant_id': 'deploy_mind_d491dbbbc8df43d09bad928051e14336'},
#  {'file': 'ES2010c.json',
#   'tenant_id': 'deploy_mind_85b5761928f644e58038da51d844433f'},
#  {'file': 'IS1007c.json',
#   'tenant_id': 'deploy_mind_19136e75e972487ab212c36f3c7c1e6f'},
#  {'file': 'ES2005c.json',
#   'tenant_id': 'deploy_mind_2b875c31c47649b0b501538bb883e281'},
#  {'file': 'IS1008c.json',
#   'tenant_id': 'deploy_mind_c90ab693e46b4b38a504c45a0c45c52e'},
#  {'file': 'IS1007d.json',
#   'tenant_id': 'deploy_mind_dbe478eb6910440c95b2e3e58186157d'},
#  {'file': 'IS1007a.json',
#   'tenant_id': 'deploy_mind_f307aa0d16194ad29582eeefe3a04f31'},
#  {'file': 'ES2006a.json',
#   'tenant_id': 'deploy_mind_d8dd3bffbab947b5aa62a8d2686b7edd'},
#  {'file': 'ES2009c.json',
#   'tenant_id': 'deploy_mind_cbcd2e6461704129ad044744f634b680'},
#  {'file': 'ES2004a.json',
#   'tenant_id': 'deploy_mind_c997f6aa9ffb4d80b70c6f7f7e6cee41'},
#  {'file': 'ES2003b.json',
#   'tenant_id': 'deploy_mind_a3246e7cbbcf42c8b0ee6da8501730cf'},
#  {'file': 'ES2010a.json',
#   'tenant_id': 'deploy_mind_246618cad6bf40369ff7ad882eb09989'},
#  {'file': 'IS1009c.json',
#   'tenant_id': 'deploy_mind_3a5c60063972494ba4746f930bb5e874'},
#  {'file': 'IS1003c.json',
#   'tenant_id': 'deploy_mind_1b61ed81e5d942d686e55bc8f5ea8113'},
#  {'file': 'ES2003d.json',
#   'tenant_id': 'deploy_mind_293a92c717c1422b971bdb6c05efc41c'},
#  {'file': 'IS1004b.json',
#   'tenant_id': 'deploy_mind_6eaf28fbe74747aaacfd2dbfb43ebddc'}]

# %%
columns = ['file', 'tenant_id']
df =pd.DataFrame(data)
df.to_csv("rag_monitoring/tenant_id.csv", mode="w", header=True, index=False,columns=columns)

# %% [markdown]
# # Generate Answer

# %%
# Read tenant_id 
import pandas as pd 
path = '/datadrive/CuongHV/project/mm_agenda_generation_research/rag_monitoring/tenant_id.csv'
data = pd.read_csv(path)
data.head()
# Out:
#            file                                     tenant_id
# 0  ES2004d.json  deploy_mind_81d33437db5d446ab045abac31d33c3b
# 1  ES2008b.json  deploy_mind_3ea93cd23e3842cc917060e649e8985b
# 2  IS1004d.json  deploy_mind_09280add1a10419c8919f5dd44f370d3
# 3  IS1008a.json  deploy_mind_8d5bd42fd4d54281ae71dba89cf81719
# 4  IS1004a.json  deploy_mind_a77940965a4c4faaae895ee479b43a5c

# %%
id = data['tenant_id'][0]
id
# Out:
# 'deploy_mind_81d33437db5d446ab045abac31d33c3b'

# %%
from dotenv import load_dotenv
load_dotenv("/datadrive/CuongHV/project/mm_agenda_generation_research/.env")


from src.utils import utils
from langchain_core.tracers.context import tracing_v2_enabled
from src.config.llm_config import llm_config

file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
prompt_config = utils.load_config(file_config["llm_env"]["prompting_file"])
config_llm = llm_config(prompt_config, model_config)
# Out:
# Loading config from file_config

# %%
import os 
config = config_llm.chose_llm_model(use_redis=False)
# config = config_llm.chose_llm_embedding()
config = config_llm.chose_llm_embedding(
    llm_model = 'OpenAI',
    model = 'text-embedding-3-small'
)
INDEX = os.environ.get("COLLECTION_ID")
config = config_llm.config_db(index=INDEX, text_key='text', tenant_name=id)
config
# Out:
# {'knowledge_configure': {'knowledge_driver': src.driver.weaviatedb.WeaviateDB},
#  'history_store': {'history_driver': src.driver.redisdb.RedisDB},
#  'condense_question_configure': {'llm_core': langchain_openai.chat_models.base.ChatOpenAI,
#   'llm_core_params': {'temperature': 0, 'model': 'gpt-4o-mini'},
#   'prompt_core_template': 'Given a chat history and the latest user question which might reference context in the chat history, \nformulate a standalone question which can be understood without the chat history. \nDo NOT answer the question, just reformulate it if needed and otherwise return it as is.\n',
#   'index_db': 'LangChain_agd_7bb158e64c93bea491df09894psd',
#   'text_key': 'text',
#   'tenant_name': 'deploy_mind_81d33437db5d446ab045abac31d33c3b'},
#  'combine_docs_configure': {'llm_core': langchain_openai.chat_models.base.ChatOpenAI,
#   'llm_core_params': {'temperature': 0, 'model': 'gpt-4o-mini'},
#   'prompt_core_template': "You are an insightful assistant, providing tailored responses based on pertinent context, emphasizing precision and clarity.\n\nInstruction:\n  + Review the provided context\n  + Respond to the user's query\n  + Offer a thorough and detailed explanation\n  + Avoid including personal opinions or conclusions\n\nContext for Reference:\n{context}\n\nAnswer:\n"},
#  'stack_chain': {'runnable_chain': False},
#  'embedding_configure': {'embedding': OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x7fb87c5ae4a0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x7fb87c2c7940>, model='text-embedding-3-small', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)}}

# %%
from langchain_weaviate.vectorstores import WeaviateVectorStore as WeaviateLC
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv
load_dotenv(".env")
import weaviate
client = weaviate.connect_to_custom(
    http_host= os.environ.get("WEAVIATE_HOST"), #"10.100.224.34",  # URL only, no http prefix
    http_port= os.environ.get("WEAVIATE_HOST_PORT"), #"8080",
    http_secure=False ,   # Set to True if https
    grpc_host= os.environ.get("WEAVIATE_GPC_URL"),#  "10.100.224.34",
    grpc_port= os.environ.get("WEAVIATE_GPC_URL_PORT"),#"50051",      # Default is 50051, WCD uses 443
    grpc_secure=False,   # Edit as needed
    skip_init_checks=True,
)
tenant_name = id
text_key = 'text'
k =2
llm_embedding = config['embedding_configure']['embedding']
vectorstore = WeaviateLC(
                client=client,
                index_name=INDEX,
                text_key='text',
                embedding=llm_embedding,
                use_multi_tenancy=True,
            )
# Out:
# /home/ad/miniconda3/envs/mm_agenda_generation_research/lib/python3.10/site-packages/weaviate/warnings.py:314: ResourceWarning: Con004: The connection to Weaviate was not closed properly. This can lead to memory leaks.
#             Please make sure to close the connection using `client.close()`.
#   warnings.warn(

# %%
query =  "What are the main objectives and focus areas of the meeting?"
retrivee_docs = vectorstore.similarity_search(query, tenant=id, k=5)
retrivee_docs
# Out:
# [Document(metadata={'filename': 'ES2004docs.ES2004scen.participant3hBcQuestionnairePre.doc'}, page_content='16. Do you feel that the objectives for your meetings are generally attained?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n17. Do you feel that the time for your meetings is generally well-spent?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n18. Do you generally like to participate in your meetings?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n19. Which of the following do you make use of before a meeting (to prepare for the meeting)?\nMinutes of the previous meeting(s)\nRelated documents\nAgenda*\nPersonal recollection\nContact other participants*\nPersonal notes of the previous meeting(s)*\nMeans to prepare a presentation*\nPictures of previous meeting(s)\nAudio recording of previous meeting(s)\nVideo recording of previous meeting(s)\nConsult external information sources (e.g. internet)*\nContact external people (face-to-face, e-mail, telephone)\nOther:'),
#  Document(metadata={'filename': 'ES2004docs.ES2004scen.participant3hBcQuestionnairePre.doc'}, page_content='10. Which of the following devices do you own or use regularly?\nLaptop\nMobile Phone*\nPDA\nMP3-player\nNone of the above\n\n\nMeeting experience\n\n11. How often do you participate in meetings?\nNever\nMonthly\nWeekly*\nDaily - once\nDaily - more than once\n12. What is approximately the typical size of your meetings?\n____6____ number of participants\n\n13. What is approximately the typical length of your meetings?\n_____90___ minutes\n\n14. How would you characterize your typical meetings (e.g. subject matter, objective, atmosphere)?\nMostly group meeting for group assignments on academic subjects such as Strategy Management, Finance. The meetings involve brainstorming, task allocation and task fulfillment. Mostly, very enriching.\n\n15. What role(s) do you typically perform in meetings?\nChairman*\nDraw up the minutes\nParticipant*\nOther:  \n\n16. Do you feel that the objectives for your meetings are generally attained?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways'),
#  Document(metadata={'filename': 'ES2004docs.ES2004scen.Summaries.P2Sum2.txt'}, page_content="present during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role's perspective.\nWe decided on the design of the project internally and externally, =\nalso we looked at the target audiences that we will be appealing to.\nMost of the meeting was concerened with external design issues and =\nmarketing aims.=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\nDesign Element Internal*\nDesign Elements External*\nTarget Audience Aims\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\nNone really, though I feel the team may be getting too focused on ="),
#  Document(metadata={'filename': 'ES2004docs.ES2004scen.participant4hBcQuestionnairePre.doc'}, page_content='13. What is approximately the typical length of your meetings?\n___45-60_____ minutes\n\n14. How would you characterize your typical meetings (e.g. subject matter, objective, atmosphere)?  Mainly work-focused [health & fitness issues, public health, safety etc], objectives may be related to programme format, budgeting issues, staffing, programme success, etc., atmosphere is semi-formal i.e. focused but relaxed.\n\n\n15. What role(s) do you typically perform in meetings?\nChairman\nDraw up the minutes\nParticipant*\nOther:  \n\n16. Do you feel that the objectives for your meetings are generally attained?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n17. Do you feel that the time for your meetings is generally well-spent?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways\n\n18. Do you generally like to participate in your meetings?\nNever\nHardly ever\nSometimes\nMost of the times*\nAlways'),
#  Document(metadata={'filename': 'ES2004docs.ES2004scen.Summaries.P2Sum3.txt'}, page_content="present during the meeting=20\n=20\nThe head of your department\n=20\n=20\n[ABSTRACT]   Write one paragraph of coherent text to summarize the =\nmeeting as a whole from your role's perspective.\n=20\nThe meeting went well, and lots of points were raised and desisions =\nmad particularly those regarding the physical design of the phone.\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n=20\n[DECISIONS]   Name all decisions that were made during the meeting. =\nMark those decisions that you consider of high importance for your role =\nwith a *. Write fragmented notes.\nKinetic Battery combo*\nLCD Touch screen*\nAnti-RSI Rubberised buttons=20\nRubber Facias\nMain body plastic\n=20\n=20\n=20\n=20\n=20\n=20\n[PROBLEMS/ISSUES] Name the problems or difficulties that occurred =\nduring the meeting. Mark those that you consider of high importance for =\nyour role with a *. Write fragmented notes.\nThe main problems that were solved this meeting were those related to =\nthe power source and those of the contol interface.\n=20\n=20\n=20\n=20\n=20")]

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.prompts import (
    ChatPromptTemplate,
    PromptTemplate
)
from langchain_weaviate.vectorstores import WeaviateVectorStore as WeaviateLC

# Combine docs
llm_core = config['combine_docs_configure']['llm_core']
llm_core_params = config['combine_docs_configure']['llm_core_params']
prompt_core_template = config['combine_docs_configure']['prompt_core_template']
llm = llm_core(**llm_core_params)
knowledge_driver = config['knowledge_configure']['knowledge_driver']

qa_prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", prompt_core_template),
                    ("human", "{input}"),
                ]
            )
customDocumentPrompt_template= """
Context: |
    {page_content}
"""
customDocumentPrompt = PromptTemplate(
                    input_variables=['page_content', 'source'],
                    template=customDocumentPrompt_template,
                )
question_answer_chain = create_stuff_documents_chain(
    llm=llm, 
    prompt = qa_prompt,
    document_prompt = customDocumentPrompt,
    document_variable_name = "context",
)

# %%
question= "What are the main objectives and focus areas of the meeting?"
with tracing_v2_enabled(project_name = "generated_rag_multi_input_agenda"):
    output = question_answer_chain.invoke({
        'input': question,
        'context': retrivee_docs,
    })
print(output)
# Out:
# The main objectives and focus areas of the meeting can be summarized as follows:
#
# 1. **Design Decisions**: A significant portion of the meeting was dedicated to discussing both internal and external design elements of a project. This includes decisions regarding the physical design aspects, such as materials and features of a product (e.g., a phone).
#
# 2. **Target Audience Identification**: The meeting involved identifying and discussing the target audiences that the project aims to appeal to, which is crucial for tailoring marketing strategies and design features.
#
# 3. **Marketing Aims**: There was a focus on external design issues that relate to marketing objectives, ensuring that the product aligns with market needs and consumer preferences.
#
# 4. **Task Allocation and Fulfillment**: The meetings also served as a platform for brainstorming, task allocation, and ensuring that team members are clear on their responsibilities related to the project.
#
# 5. **Problem Solving**: Addressing any issues or difficulties that arose during the meeting, particularly those related to design and functionality, was also a key focus area.
#
# Overall, the meetings are characterized by a collaborative atmosphere aimed at achieving specific project goals through structured discussions and decision-making processes.

# %% [markdown]
# The main objectives and focus areas of the meeting included:
#
# 1. **Introductions**: Participants shared their favorite animals through a drawing exercise.
# 2. **Project Overview**: Discussion of major project areas such as Industrial Design, User-Interaction Design, and Marketing.
# 3. **Group Discussion**: Focus on user-friendly design issues, particularly exploring mobile phone designs for adaptation in TV remote controls.
# 4. **Decision Making**: Reaching consensus on specifications and design elements for the Remote Control device.

# %% [markdown]
# # Generate the answers for 67 meetings

# %%
from dotenv import load_dotenv
load_dotenv("/datadrive/CuongHV/project/mm_agenda_generation_research/.env")


from src.utils import utils
from langchain_core.tracers.context import tracing_v2_enabled
from src.config.llm_config import llm_config
import os 

file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
prompt_config = utils.load_config(file_config["llm_env"]["prompting_file"])
config_llm = llm_config(prompt_config, model_config)
config = config_llm.chose_llm_model(use_redis=False)
# config = config_llm.chose_llm_embedding()
config = config_llm.chose_llm_embedding(
    llm_model = 'OpenAI',
    model = 'text-embedding-3-small'
)
INDEX = os.environ.get("COLLECTION_ID")
config = config_llm.config_db(index=INDEX, text_key='text', tenant_name=id)
# Out:
# Loading config from file_config

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.prompts import (
    ChatPromptTemplate,
    PromptTemplate
)
from langchain_weaviate.vectorstores import WeaviateVectorStore as WeaviateLC

# Combine docs
llm_core = config['combine_docs_configure']['llm_core']
llm_core_params = config['combine_docs_configure']['llm_core_params']
prompt_core_template = config['combine_docs_configure']['prompt_core_template']
llm = llm_core(**llm_core_params)
llm_embedding = config['embedding_configure']['embedding']

qa_prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", prompt_core_template),
                    ("human", "{input}"),
                ]
            )
customDocumentPrompt_template= """
Context: |
    {page_content}
"""
customDocumentPrompt = PromptTemplate(
                    input_variables=['page_content', 'filename'], #Filename use for the production, retrieve the evident for user
                    template=customDocumentPrompt_template,
                )
question_answer_chain = create_stuff_documents_chain(
    llm=llm, 
    prompt = qa_prompt,
    document_prompt = customDocumentPrompt,
    document_variable_name = "context",
)

# %%
import weaviate
client = weaviate.connect_to_custom(
    http_host= os.environ.get("WEAVIATE_HOST"), #"10.100.224.34",  # URL only, no http prefix
    http_port= os.environ.get("WEAVIATE_HOST_PORT"), #"8080",
    http_secure=False ,   # Set to True if https
    grpc_host= os.environ.get("WEAVIATE_GPC_URL"),#  "10.100.224.34",
    grpc_port= os.environ.get("WEAVIATE_GPC_URL_PORT"),#"50051",      # Default is 50051, WCD uses 443
    grpc_secure=False,   # Edit as needed
    skip_init_checks=True,
)
vectorstore = WeaviateLC(
                client=client,
                index_name=INDEX,
                text_key='text',
                embedding=llm_embedding,
                use_multi_tenancy=True,
            )
vectorstore

# %%
def answer_by_rag(
        question: str,
        tenant_id: str, 
        vectorstore: WeaviateLC,
        k: int,
):
        retrivee_docs = vectorstore.similarity_search(query=question, tenant=tenant_id, k=k)
        with tracing_v2_enabled(project_name = "generated_rag_multi_input_agenda"):
                output = question_answer_chain.invoke({
                        'input': question,
                        'context': retrivee_docs,
                })
        return output

# %%
# load file and tenant_id 
 # Read tenant_id 
import pandas as pd 
import json 
path = '/datadrive/CuongHV/project/mm_agenda_generation_research/rag_monitoring/tenant_id.csv'
data = pd.read_csv(path)
# fixed queries:
questions_list = [
  "What are the main objectives and focus areas of the meeting?",
  "What are the latest updates on assigned tasks and significant developments?",
  "What previous action items are still pending, and what challenges were faced?",
  "What major topics need to be discussed, and what insights have been shared?",
  "What challenges are currently being faced, and what solutions have been proposed?",
  "What key decisions need to be made, and what are their implications?",
  "What are the next steps, assigned tasks, and deadlines?",
  "What follow-up actions and plans are required for the next meeting?"
]
# Create the answer:
for index, row in data.iterrows():
    file = row['file']
    print(file)
    tenant_id = row['tenant_id']
    qa = {}
    for query in questions_list:
        answer = answer_by_rag(question=query, tenant_id=tenant_id, vectorstore= vectorstore, k=10)
        qa[query] = answer 
    data = {
        'file': file,
        'qa': qa,
    }
    with open(f'/datadrive/CuongHV/project/DATA/mm_agenda_generation_research_output/qa_by_rag/{file}', 'a', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    print(f"Finish {file}")
# Out:
# ES2004d.json
# Finish ES2004d.json
# ES2008b.json
# Finish ES2008b.json
# IS1004d.json
# Finish IS1004d.json
# IS1008a.json
# Finish IS1008a.json
# IS1004a.json
# Finish IS1004a.json
# IS1005b.json
# Finish IS1005b.json
# ES2008c.json
# Finish ES2008c.json
# ES2008d.json
# Finish ES2008d.json
# IS1006d.json
# Finish IS1006d.json
# IS1006c.json
# Finish IS1006c.json
# IS1005a.json
# Finish IS1005a.json
# ES2006d.json
# Finish ES2006d.json
# ES2004b.json
# Finish ES2004b.json
# ES2009d.json
# Finish ES2009d.json
# IS1005c.json
# Finish IS1005c.json
# ES2005a.json
# Finish ES2005a.json
# ES2006b.json
# Finish ES2006b.json
# IS1001c.json
# Finish IS1001c.json
# ES2003a.json
# Finish ES2003a.json
# IS1001d.json
# Finish IS1001d.json
# IS1001a.json
# Finish IS1001a.json
# ES2002b.json
# Finish ES2002b.json
# ES2004c.json
# Finish ES2004c.json
# ES2002a.json
# Finish ES2002a.json
# ES2003c.json
# Finish ES2003c.json
# ES2008a.json
# Finish ES2008a.json
# ES2006c.json
# Finish ES2006c.json
# ES2007d.json
# Finish ES2007d.json
# IS1009d.json
# Finish IS1009d.json
# IS1009b.json
# Finish IS1009b.json
# ES2005d.json
# Finish ES2005d.json
# IS1006b.json
# Finish IS1006b.json
# ES2009b.json
# Finish ES2009b.json
# ES2010d.json
# Finish ES2010d.json
# ES2002d.json
# Finish ES2002d.json
# IS1001b.json
# Finish IS1001b.json
# IS1003b.json
# Finish IS1003b.json
# ES2007b.json
# Finish ES2007b.json
# IS1004c.json
# Finish IS1004c.json
# IS1003d.json
# Finish IS1003d.json
# ES2002c.json
# Finish ES2002c.json
# IS1008b.json
# Finish IS1008b.json
# ES2005b.json
# Finish ES2005b.json
# ES2009a.json
# Finish ES2009a.json
# IS1003a.json
# Finish IS1003a.json
# ES2010b.json
# Finish ES2010b.json
# IS1009a.json
# Finish IS1009a.json
# ES2007c.json
# Finish ES2007c.json
# IS1007b.json
# Finish IS1007b.json
# IS1006a.json
# Finish IS1006a.json
# ES2007a.json
# Finish ES2007a.json
# IS1008d.json
# Finish IS1008d.json
# ES2010c.json
# Finish ES2010c.json
# IS1007c.json
# Finish IS1007c.json
# ES2005c.json
# Finish ES2005c.json
# IS1008c.json
# Finish IS1008c.json
# IS1007d.json
# Finish IS1007d.json
# IS1007a.json
# Finish IS1007a.json
# ES2006a.json
# Finish ES2006a.json
# ES2009c.json
# Finish ES2009c.json
# ES2004a.json
# Finish ES2004a.json
# ES2003b.json
# Finish ES2003b.json
# ES2010a.json
# Finish ES2010a.json
# IS1009c.json
# Finish IS1009c.json
# IS1003c.json

# %% [markdown]
# # Review the result

# %%
import os 
root = '/datadrive/CuongHV/project/DATA/mm_agenda_generation_research_output/qa_by_rag'
files = os.listdir(root)
len(files)
# Out:
# 67

# %%
import os 
root = '/datadrive/CuongHV/project/DATA/AMI_MS_RAG_Cleaned'
files = os.listdir(root)
len(files)
# Out:
# 125

# %%
import json 
file_path = f'{root}/{files[0]}'
with open(file_path, 'r') as f:
    data = json.load(f)

data
# Out:
# {'file': 'ES2004d.json',
#  'qa': {'What are the main objectives and focus areas of the meeting?': "The main objectives and focus areas of the meeting can be summarized as follows:\n\n1. **Design Decisions**: The meeting primarily aimed to finalize the design elements of a project, both internal and external. This included discussions on specific components such as the physical design of a product, which in one context involved decisions about features like the kinetic battery combo, LCD touch screen, and anti-RSI rubberized buttons.\n\n2. **Target Audience Identification**: Another key focus was identifying and discussing the target audiences that the project would appeal to. This aspect is crucial for tailoring the design and marketing strategies effectively.\n\n3. **Marketing Aims**: The meeting also addressed marketing objectives, ensuring that the design aligns with the intended market strategy and audience engagement.\n\n4. **Problem-Solving**: The meeting provided a platform to address and resolve any issues that arose, such as budget control and financial information management, which are essential for effective project execution.\n\n5. **Collaboration and Task Allocation**: The atmosphere of the meeting encouraged brainstorming and collaboration among participants, with an emphasis on task allocation and fulfillment related to the project.\n\nOverall, the meeting was characterized by a focus on design, audience targeting, marketing strategies, and collaborative problem-solving, all aimed at achieving the project's objectives efficiently.",
#   'What are the latest updates on assigned tasks and significant developments?': 'Based on the provided context, the following updates on assigned tasks and significant developments can be summarized:\n\n1. **Assigned Tasks**:\n   - Each team member has specific actions to complete before the next meeting:\n     - **ID**: Focus on the components concept.\n     - **UID**: Work on the user interface concept.\n     - **ME**: Engage in trend watching.\n   - There is a need for team members to finalize their designs and ensure that they are prepared to report on their progress in the next meeting.\n\n2. **Significant Developments**:\n   - The meeting addressed key issues related to the power source and control interface for the remote control design.\n   - There was a discussion about the importance of maintaining focus on major project goals rather than getting sidetracked by minor details.\n   - A suggestion was made to improve budget control and financial information accessibility at the beginning of the design process.\n\n3. **Next Steps**:\n   - Team members are expected to complete a questionnaire and summarize their notes after the meeting, which will contribute to the project documentation.\n   - The Project Manager will compile the minutes and place them in the Project Documents folder for future reference.\n\nThese updates reflect the current status of tasks and the overall direction of the project as discussed in the meeting.',
#   'What previous action items are still pending, and what challenges were faced?': 'Based on the provided context, the following action items and challenges can be identified:\n\n### Pending Action Items:\n1. **Control Over Budget**: There is a need for better control over the budget and financial information during the design phase. This indicates that financial oversight is still a concern that needs to be addressed.\n2. **Voice Recognition System**: The decision to cut the voice recognition system from the prototype suggests that further evaluation or alternative solutions may be required to address the functionality that was lost.\n3. **Send Completed Design**: One of the action items mentioned is to send the completed design to the Head of Department, which implies that this task is still pending.\n4. **Start Production**: The action to start production has been noted, but it may depend on the completion of the design and resolution of any outstanding issues.\n\n### Challenges Faced:\n1. **Budget Overruns**: The product was running over budget, which led to the decision to eliminate the voice recognition system. This is marked as a high-importance issue, indicating significant financial constraints.\n2. **Control Over Financial Information**: The lack of control over the budget and financial information at the beginning of the design process has been highlighted as a problem, suggesting that this has impacted decision-making and project planning.\n3. **RSI (Repetitive Strain Injury) Concerns**: There is a question regarding whether the problem of RSI was addressed, indicating potential health and safety concerns that may not have been fully resolved.\n\nThese points summarize the pending actions and challenges faced during the meetings, reflecting ongoing issues that need to be managed moving forward.',
#   'What major topics need to be discussed, and what insights have been shared?': "Based on the provided context, the major topics that need to be discussed during the meetings include:\n\n1. **Project Overview**: This encompasses the design, manufacture, and distribution of the new remote control. It is essential to establish a clear understanding of the project's scope and objectives.\n\n2. **Design Elements**: Both internal and external design aspects are critical. Discussions should focus on how the product will look and function, including user-friendly design issues.\n\n3. **Target Audience**: Identifying and understanding the target audience is vital for tailoring the product to meet their needs and preferences.\n\n4. **Budget Considerations**: Discussions regarding the budget are necessary to understand financial constraints and how they may impact design and production decisions.\n\n5. **Group Dynamics and Team Building**: Activities such as drawing exercises help in team bonding and can foster a collaborative environment, which is important for project success.\n\n6. **Marketing Aims**: Strategies for marketing the product should be discussed, including how to position the remote control in the market.\n\nInsights shared during the meetings include:\n\n- The importance of user-friendly design, with a consensus on looking at mobile phone designs for inspiration.\n- The need for collaboration among team members to ensure all areas of the project are considered.\n- The potential for innovative design variations, as suggested by the User-Interface Designer, which will be explored in future meetings.\n- The recognition that the team may be focusing too much on minor details, which could detract from addressing more significant project issues.\n\nThese topics and insights are crucial for guiding the project and ensuring that all team members are aligned in their objectives and strategies.",
#   'What challenges are currently being faced, and what solutions have been proposed?': "Based on the provided context, several challenges have been identified during the meetings, along with proposed solutions. Here is a detailed breakdown:\n\n### Challenges Faced:\n\n1. **Budget Constraints**:\n   - The project is running over budget, leading to the rejection of certain features, such as the voice recognition function, to keep costs manageable. This is marked as a high-importance issue.\n\n2. **Design Conflicts**:\n   - There is a potential clash between the design aim of being trendy and upmarket and the budget limitations. This issue is also marked as high importance for further discussion.\n\n3. **User Requirements**:\n   - Some valuable ideas aimed at satisfying user requirements had to be discarded due to budget constraints, which could impact the overall user experience.\n\n4. **Technology Overload**:\n   - Concerns were raised about alienating older consumers by incorporating too much technology into the product, which could limit its market appeal.\n\n5. **Repetitive Strain Injury (RSI)**:\n   - There are concerns regarding the design of the handset being too small, which could lead to repetitive strain injuries for users.\n\n6. **Time Delays**:\n   - There were time delays related to changing cables for PowerPoint presentations during the meeting, which could affect the efficiency of future meetings.\n\n### Proposed Solutions:\n\n1. **Budget Management**:\n   - A recommendation was made to produce a prototype model to the Head Office, which may help in securing additional funding or resources.\n\n2. **Design Reevaluation**:\n   - The industrial designer is tasked with examining the product's functionality to ensure it meets user needs while staying within budget.\n\n3. **Material and Process Investigation**:\n   - The user interface designer will explore materials and processes involved in the product's creation, potentially leading to cost-effective solutions.\n\n4. **Market Analysis**:\n   - The marketing expert will analyze current market trends to align the product with consumer expectations and preferences, ensuring it appeals to the target demographic.\n\n5. **Focus on Ergonomics**:\n   - The UI designer will investigate the shape and button design of the control to address concerns about RSI, ensuring the product is user-friendly.\n\n6. **Simplification of Features**:\n   - The decision to eliminate complex programming functions in favor of simpler alternatives (like 'video plus') aims to streamline the product and reduce costs.\n\nThese challenges and proposed solutions highlight the ongoing efforts to balance design aspirations with practical constraints, ensuring the product remains viable and appealing to its intended audience.",
#   'What key decisions need to be made, and what are their implications?': "To provide a comprehensive response regarding key decisions and their implications, it is essential to first identify the specific context or area of focus. However, based on general organizational decision-making, here are some common key decisions that may need to be made, along with their potential implications:\n\n1. **Strategic Direction**:\n   - **Decision**: Choosing a long-term strategic direction for the organization (e.g., market expansion, product development).\n   - **Implications**: This decision affects resource allocation, operational focus, and can influence the organization's competitive positioning in the market.\n\n2. **Budget Allocation**:\n   - **Decision**: Determining how to allocate the budget across different departments or projects.\n   - **Implications**: This impacts operational capabilities, project viability, and can affect employee morale and productivity if certain areas are underfunded.\n\n3. **Hiring and Staffing**:\n   - **Decision**: Deciding on hiring new staff or restructuring existing teams.\n   - **Implications**: This can influence team dynamics, organizational culture, and the ability to meet strategic goals. It also affects costs and resource management.\n\n4. **Technology Adoption**:\n   - **Decision**: Selecting new technologies or systems to implement.\n   - **Implications**: This can lead to improved efficiency and productivity but may also require training and adjustment periods for staff, as well as potential disruptions during the transition.\n\n5. **Policy Changes**:\n   - **Decision**: Implementing new policies or changing existing ones (e.g., remote work policies, compliance regulations).\n   - **Implications**: This can affect employee satisfaction, legal compliance, and operational procedures. It may also require communication and training efforts to ensure understanding and adherence.\n\n6. **Partnerships and Collaborations**:\n   - **Decision**: Forming strategic partnerships or collaborations with other organizations.\n   - **Implications**: This can enhance capabilities and market reach but may also involve risks related to brand alignment, shared resources, and dependency on partners.\n\n7. **Crisis Management**:\n   - **Decision**: Developing a response plan for potential crises (e.g., financial downturns, public relations issues).\n   - **Implications**: Effective crisis management can mitigate damage and maintain stakeholder trust, while poor decisions can lead to long-term reputational harm and financial loss.\n\nEach of these decisions carries significant implications that can affect various aspects of the organization, including financial performance, employee engagement, and overall strategic success. It is crucial for decision-makers to consider these implications carefully and engage relevant stakeholders in the decision-making process.",
#   'What are the next steps, assigned tasks, and deadlines?': 'Based on the provided context, the next steps, assigned tasks, and deadlines for each member until the next meeting can be summarized as follows:\n\n1. **Industrial Designer**:\n   - **Task**: Review product functionality and requirements.\n   - **Deadline**: Before the next meeting.\n\n2. **Team Member (not specified)**:\n   - **Task**: Send completed design to the Head of Department.\n   - **Deadline**: Before the next meeting.\n\n3. **Team Member (not specified)**:\n   - **Task**: Start production.\n   - **Deadline**: Before the next meeting.\n\n4. **All Team Members**:\n   - **Task**: Complete a short questionnaire for documentation of the design project.\n   - **Deadline**: Before the next meeting.\n\nThese tasks are fragmented notes indicating the responsibilities assigned to team members, with an emphasis on completing them prior to the next scheduled meeting.',
#   'What follow-up actions and plans are required for the next meeting?': 'Based on the provided context, the following follow-up actions and plans are required for the next meeting:\n\n1. **Send Completed Design to Head of Department**: Ensure that the finalized design is submitted for review and approval.\n\n2. **Start Production**: Initiate the production process based on the approved design.\n\n3. **Control Over Budget**: Review and implement measures to gain better control over the budget, particularly in relation to the financial information that was needed during the design phase.\n\n4. **Address Voice Recognition System**: Evaluate the decision to cut the voice recognition system from the prototype and discuss potential alternatives or solutions to incorporate it back into the project if feasible.\n\n5. **Combat RSI (Repetitive Strain Injury)**: Follow up on the strategies discussed to address RSI and ensure that any necessary actions are taken to mitigate this issue.\n\nThese actions should be assigned to specific team members, with deadlines set to ensure accountability and progress before the next meeting.'}}

# %%
len(data['qa'])
# Out:
# 8

# %%
checked_data = []
for file in files:
    with open(f'{root}/{file}', 'r') as f:
        data = json.load(f)
    if len(data['qa']) == 8:
        checked_data.append(file)

# %%
len(checked_data)
# Out:
# 67

# %%
file_path_0 = f'{root}/{files[0]}'
with open(f'{root}/{file}', 'r') as f:
    data = json.load(f)
print(data['qa']['What are the main objectives and focus areas of the meeting?'])
# Out:
# The main objectives and focus areas of the meeting can be summarized as follows:
#
# 1. **Product Development**: The meeting aimed to refine the specifications of the product, ensuring that it aligns with the initial requirements and expectations. This includes discussing the features and design elements that would appeal to the target market.
#
# 2. **Target Market Identification**: A significant focus was on identifying and agreeing upon the target market for the product. This is crucial as it influences the product's features, design, and marketing strategy.
#
# 3. **Evaluation of Product Appeal**: The meeting addressed the need for the final product to be visually appealing and marketable. Discussions highlighted the importance of aesthetics alongside functionality to ensure the product's success in the market.
#
# 4. **Budget Considerations**: Budget constraints were a recurring theme, with discussions on how to maintain cost-effectiveness while achieving the desired product specifications and features.
#
# 5. **Next Steps and Action Items**: The meeting concluded with outlining the next steps for each team member, focusing on gathering ideas and refining product characteristics based on the discussions held.
#
# Overall, the meeting was centered on aligning the team’s vision for the product, addressing potential issues, and planning actionable steps to move forward effectively.

# %% [markdown]
# The main objectives and focus areas of the meeting can be summarized as follows:
#
# 1. **Product Development**: The meeting aimed to refine the specifications of the product, ensuring that it aligns with the initial requirements and expectations. This includes discussing the features and design elements that would appeal to the target market.
#
# 2. **Target Market Identification**: A significant focus was on identifying and agreeing upon the target market for the product. This is crucial as it influences the product's features, design, and marketing strategy.
#
# 3. **Evaluation of Product Appeal**: The meeting addressed the need for the final product to be visually appealing and marketable. Discussions highlighted the importance of aesthetics alongside functionality to ensure the product's success in the market.
#
# 4. **Budget Considerations**: Budget constraints were a recurring theme, with discussions on how to maintain cost-effectiveness while achieving the desired product specifications and features.
#
# 5. **Next Steps and Action Items**: The meeting concluded with outlining the next steps for each team member, focusing on gathering ideas and refining product characteristics based on the discussions held.
#
# Overall, the meeting was centered on aligning the team’s vision for the product, addressing potential issues, and planning actionable steps to move forward effectively.

# %%
file_path_1 = f'{root}/{files[1]}'
with open(f'{root}/{file}', 'r') as f:
    data = json.load(f)
print(data['qa']['What are the main objectives and focus areas of the meeting?'])
# Out:
# The main objectives and focus areas of the meeting can be summarized as follows:
#
# 1. **Product Development**: The meeting aimed to refine the specifications of the product, ensuring that it aligns with the initial requirements and expectations. This includes discussing the features and design elements that would appeal to the target market.
#
# 2. **Target Market Identification**: A significant focus was on identifying and agreeing upon the target market for the product. This is crucial as it influences the product's features, design, and marketing strategy.
#
# 3. **Evaluation of Product Appeal**: The meeting addressed the need for the final product to be visually appealing and marketable. Discussions highlighted the importance of aesthetics alongside functionality to ensure the product's success in the market.
#
# 4. **Budget Considerations**: Budget constraints were a recurring theme, with discussions on how to maintain cost-effectiveness while achieving the desired product specifications and features.
#
# 5. **Next Steps and Action Items**: The meeting concluded with outlining the next steps for each team member, focusing on gathering ideas and refining product characteristics based on the discussions held.
#
# Overall, the meeting was centered on aligning the team’s vision for the product, addressing potential issues, and planning actionable steps to move forward effectively.

# %% [markdown]
# The main objectives and focus areas of the meeting can be summarized as follows:
#
# 1. **Product Development**: The meeting aimed to refine the specifications of the product, ensuring that it aligns with the initial requirements and expectations. This includes discussing the features and design elements that would appeal to the target market.
#
# 2. **Target Market Identification**: A significant focus was on identifying and agreeing upon the target market for the product. This is crucial as it influences the product's features, design, and marketing strategy.
#
# 3. **Evaluation of Product Appeal**: The meeting addressed the need for the final product to be visually appealing and marketable. Discussions highlighted the importance of aesthetics alongside functionality to ensure the product's success in the market.
#
# 4. **Budget Considerations**: Budget constraints were a recurring theme, with discussions on how to maintain cost-effectiveness while achieving the desired product specifications and features.
#
# 5. **Next Steps and Action Items**: The meeting concluded with outlining the next steps for each team member, focusing on gathering ideas and refining product characteristics based on the discussions held.
#
# Overall, the meeting was centered on aligning the team’s vision for the product, addressing potential issues, and planning actionable steps to move forward effectively.

# %% [markdown]
# # Based on qa_by_rag, and template, create the agenda

# %%
# load qa_by_rag
import json
def load_qa_from_file(file, root:str = "/datadrive/CuongHV/project/DATA/mm_agenda_generation_research_output/qa_by_rag"):
    with open(f'{root}/{file}', 'r') as f:
        data = json.load(f)
    lines = [f'Question:{q}\nAnswer:{a}' for q,a in data['qa'].items()]
    qa_text = '\n'.join(lines)
    return qa_text

# %%
qa_text = load_qa_from_file('ES2002a.json')
print(qa_text)
# Out:
# Question:What are the main objectives and focus areas of the meeting?
# Answer:The main objectives and focus areas of the meeting can be summarized as follows:
#
# 1. **Finalization of Design Prototype**: The meeting aimed to finalize the design prototype of the product, ensuring that all team members were aligned on the final design elements.
#
# 2. **Review of Cost Constraints**: A significant focus was placed on reviewing the financial constraints that impacted the design, including discussions on which features could be retained or had to be removed due to budget limitations.
#
# 3. **Evaluation of Project Success**: The meeting included an evaluation of the overall success of the project, assessing whether the objectives set at the beginning were met and how the team performed throughout the project lifecycle.
#
# 4. **Clarification of Roles and Responsibilities**: There was a need to clarify the roles and responsibilities of team members, as some members expressed uncertainty about their specific tasks and contributions to the project.
#
# 5. **Discussion of Product Functionality**: The team discussed the essential functionalities of the product, determining what features were necessary to appeal to the target market while adhering to the set price point.
#
# 6. **Addressing Team Dynamics**: The meeting highlighted the importance of team dynamics, including the need for better communication and collaboration among team members, as well as the impact of the meeting environment on productivity.
#
# 7. **Action Planning for Next Steps**: Although there was a noted lack of clear directives, the meeting aimed to outline the next steps for each team member to ensure progress before the next meeting.
#
# These objectives reflect the need for both strategic planning and operational clarity to move the project forward effectively.
# Question:What are the latest updates on assigned tasks and significant developments?
# Answer:Based on the provided context, here are the latest updates on assigned tasks and significant developments:
#
# 1. **Assigned Tasks:**
#    - **David (ID)**: Focused on understanding the limitations imposed by costs and determining what functionalities can be provided within the financing restraints.
#    - **Andrew (ME)**: Tasked with exploring how to market the product to different countries and identifying key selling points.
#    - **Craig (UID)**: Responsible for developing the technical specifications of the product.
#    - **Laura (Project Manager)**: Acted as the secretary for the meeting and is responsible for documenting the minutes and ensuring they are placed in the Project Documents folder.
#
# 2. **Significant Developments:**
#    - The basic functionality of the product has been determined, including audio, video, and sound features.
#    - A "bucket system" has been established to categorize the functionalities of the product.
#    - Decisions were made to eliminate certain features to maintain production costs, including the removal of the LCD screen and color in buttons.
#    - Advanced functions have been replaced by a scroll wheel to further reduce costs.
#    - There is an ongoing uncertainty regarding the inclusion of voice recognition technology in the product.
#
# 3. **Next Steps:**
#    - Each team member is expected to continue working on their assigned tasks until the next meeting, with no clear directives issued during the last meeting.
#    - Individual actions include developing the components concept (ID), user interface concept (UID), and trend watching (ME).
#
# These updates reflect the current status of the project and the tasks assigned to each team member, as well as the decisions made during the meetings.
# Question:What previous action items are still pending, and what challenges were faced?
# Answer:Based on the provided context, the following action items are still pending, along with the associated challenges faced during the meetings:
#
# ### Pending Action Items:
# 1. **Team Role Clarification**: There is still uncertainty regarding the specific roles and responsibilities of team members, which needs to be addressed to enhance collaboration and efficiency.
# 2. **Market Strategy Development**: Andrew is tasked with determining how to market the product to different countries and identifying selling points, but this may require further discussion and alignment with the team.
# 3. **Technical Specifications**: Craig is responsible for developing the technical specifications, which may be impacted by the financial constraints and decisions made regarding product features.
# 4. **Final Design Confirmation**: Although a decision was made to proceed with the final design, there may still be outstanding details that need to be finalized before moving forward.
#
# ### Challenges Faced:
# 1. **Lack of Clarity on Roles**: Team members expressed uncertainty about their individual roles, which can hinder productivity and accountability.
# 2. **Financial Constraints**: Budget limitations led to the removal of certain design features, impacting the overall product vision and functionality.
# 3. **Communication Issues**: There was a noted lack of vocal participation from some team members, which may affect the flow of ideas and collaboration.
# 4. **Time Management**: Meetings were constrained by time, leading to insufficient discussion on critical topics and an overload of information that was difficult to digest.
# 5. **Strict Agenda**: The enforcement of a strict agenda limited the flexibility of discussions, potentially stifling creativity and the natural flow of ideas.
# 6. **Distractions**: The presence of multiple devices and a lack of a central focus point in the meeting room may have contributed to distractions, affecting engagement and attention.
#
# These pending action items and challenges highlight the need for improved communication, role definition, and meeting management to facilitate better outcomes in future meetings.
# Question:What major topics need to be discussed, and what insights have been shared?
# Answer:Based on the provided context, the major topics that need to be discussed during the meetings include:
#
# 1. **Product Definition and Design**:
#    - The overall design and aesthetic appeal of the product, including materials (plastic and rubber) and features (such as backlighting and jog dial).
#    - The shape of the product, which has been decided to be a "snowman" shape.
#    - The importance of the product's look and feel, ensuring it aligns with corporate branding (corporate color and slogan).
#
# 2. **Functionality and Features**:
#    - Discussion on the functionalities of the remote control, including the need to control multiple devices and the organization of features (audio, video, device controls).
#    - Consideration of what functionalities can be realistically included within budget constraints.
#
# 3. **Market Positioning**:
#    - Target demographic for the product, specifically focusing on the international 15-35 age group.
#    - Positioning the product as a high-end offering in terms of design and price, while keeping features user-friendly and not overly complex.
#
# 4. **Team Dynamics and Roles**:
#    - Clarification of team members' roles and responsibilities, as there is uncertainty regarding individual strengths and weaknesses.
#    - The need for improved communication and collaboration among team members, as current tools and meeting structures hinder effective teamwork.
#
# 5. **Meeting Structure and Effectiveness**:
#    - Evaluation of the meeting format, including time management and the balance between structured agendas and open discussions.
#    - Addressing the distractions caused by technology and the physical meeting environment, which may impede the flow of ideas.
#
# Insights shared during the meetings include:
# - The recognition that creative input is essential but may be stifled by financial and time constraints.
# - The need for a more relaxed environment to foster creativity and collaboration.
# - Acknowledgment of the challenges posed by strict agendas and the necessity to focus on quality discussions rather than merely completing a checklist of topics.
# - The importance of establishing familiarity among team members to enhance teamwork and communication.
#
# These topics and insights highlight the multifaceted nature of the project, encompassing design, functionality, market strategy, team dynamics, and meeting effectiveness.
# Question:What challenges are currently being faced, and what solutions have been proposed?
# Answer:Based on the provided context, several challenges have been identified during the meetings, along with some proposed solutions. Here is a detailed breakdown:
#
# ### Challenges Faced:
#
# 1. **Communication Issues:**
#    - Team members were not very vocal during meetings, leading to uncertainty about roles and responsibilities.
#    - There was a lack of effective communication tools, making collaboration difficult outside of meetings.
#
# 2. **Role Clarity:**
#    - Team members expressed confusion regarding their specific roles and responsibilities within the project, which hindered productivity.
#
# 3. **Time Constraints:**
#    - Meetings were often short, with too much data to discuss, leading to insufficient time for thorough evaluation and discussion.
#    - Strict agendas limited the flow of conversation and flexibility in addressing important topics.
#
# 4. **Technical Distractions:**
#    - The presence of multiple devices (laptops, projectors) distracted team members and hindered the flow of ideas.
#    - The meeting environment lacked a focal point, making it difficult for team members to engage effectively.
#
# 5. **Financial Constraints:**
#    - Budget limitations forced the removal of certain design features, which could impact the product's appeal and functionality.
#
# 6. **Creativity Limitations:**
#    - Financial and time constraints restricted the creative process, leading to a less innovative design approach.
#
# ### Proposed Solutions:
#
# 1. **Improved Communication:**
#    - Encourage team members to express their thoughts and ideas more freely, possibly by establishing a more open and relaxed meeting environment.
#    - Utilize more effective collaboration tools to facilitate communication outside of meetings.
#
# 2. **Clarification of Roles:**
#    - Conduct a session to clearly define each team member's roles and responsibilities, ensuring everyone understands their contributions to the project.
#
# 3. **Meeting Structure Adjustments:**
#    - Consider revising the meeting structure to allow for more open discussion and flexibility, rather than strictly adhering to a predetermined agenda.
#    - Schedule separate meetings focused on team evaluation and project evaluation to ensure both aspects receive adequate attention.
#
# 4. **Minimizing Distractions:**
#    - Limit the use of technology during meetings to reduce distractions, possibly by using whiteboards instead of presentations.
#    - Create a more focused meeting environment by designating a central point of attention, such as a whiteboard or a specific team member.
#
# 5. **Addressing Financial Constraints:**
#    - Explore alternative design features that can be included within the budget, or consider adjusting the product's pricing strategy to accommodate desired features.
#
# 6. **Fostering Creativity:**
#    - Create a more relaxed and conducive environment for brainstorming and creative thinking, possibly by reducing the use of technical gear during discussions.
#
# By addressing these challenges with the proposed solutions, the team can enhance collaboration, clarify roles, and improve the overall effectiveness of their meetings and project outcomes.
# Question:What key decisions need to be made, and what are their implications?
# Answer:Based on the provided contexts, several key decisions need to be made regarding the product development of the TV remote control. Here are the identified decisions along with their implications:
#
# 1. **Product Shape and Design**:
#    - Decision: The product will have a "Snowman" shape and will be designed to be trendy and appealing to a chic, fashionable audience.
#    - Implications: This decision affects the aesthetic appeal of the product, which is crucial for attracting the target demographic (ages 15-35). It may also influence manufacturing processes and costs associated with creating unique shapes.
#
# 2. **Material Selection**:
#    - Decision: The product will be made of plastic and rubber.
#    - Implications: This choice impacts the durability, cost, and overall feel of the product. It may also affect the environmental considerations and sustainability of the product.
#
# 3. **Functionality Features**:
#    - Decision: The product will eliminate the LCD display and will not include "talk back" features, focusing instead on basic controls and a jog dial mechanism.
#    - Implications: This decision simplifies the product, potentially reducing costs and complexity. However, it may limit the functionality and user experience, which could affect market competitiveness.
#
# 4. **Target Market**:
#    - Decision: The product will be marketed internationally to a specific age group (15-35) and positioned as a high-end product.
#    - Implications: This decision will guide marketing strategies, pricing, and feature sets. It necessitates a clear understanding of the preferences and behaviors of the target demographic to ensure successful market penetration.
#
# 5. **Pricing Strategy**:
#    - Decision: The product will be manufactured for a specific cost (12.50) and sold at a retail price (25).
#    - Implications: This pricing strategy will influence profit margins and market positioning. It requires careful consideration of production costs, competitive pricing, and perceived value by consumers.
#
# 6. **Feature Grouping**:
#    - Decision: Functions will be grouped into categories (audio, video, and other).
#    - Implications: This organization will affect the user interface design and overall usability of the product. It is essential for ensuring that users can easily navigate and access the desired features.
#
# 7. **Inclusion of Voice Recognition**:
#    - Decision: There is a differing opinion on whether to include voice recognition as a function.
#    - Implications: This decision could significantly impact the product's appeal and functionality. Including advanced features like voice recognition may attract tech-savvy consumers but could also increase costs and complexity.
#
# 8. **Next Steps and Team Roles**:
#    - Decision: Clear roles and responsibilities need to be defined for team members.
#    - Implications: Establishing clear roles will enhance team efficiency and accountability, ensuring that all aspects of the project are addressed effectively.
#
# In summary, these decisions are critical as they will shape the product's design, functionality, market positioning, and overall success in the competitive landscape of consumer electronics. Each decision carries implications that must be carefully evaluated to align with the project's goals and the target market's expectations.
# Question:What are the next steps, assigned tasks, and deadlines?
# Answer:Based on the provided context, here are the next steps, assigned tasks, and deadlines for each team member:
#
# 1. **David (ID)**:
#    - Task: Assess limitations imposed by costs and determine what functionalities can be provided within the financing restraints.
#    - Deadline: Until the next meeting.
#
# 2. **Andrew (ME)**:
#    - Task: Develop a marketing strategy for the product, focusing on how to market it to different countries and identifying key selling points.
#    - Deadline: Until the next meeting.
#
# 3. **Craig (UID)**:
#    - Task: Work on the technical specifications of the product.
#    - Deadline: Until the next meeting.
#
# 4. **Industrial Designer**:
#    - Task: Refine the working design, specify components based on requirements, and research the viability of voice recognition technology for the product.
#    - Deadline: Until the next meeting.
#
# 5. **Marketing**:
#    - Task: Clarify the marketing requirements for the product.
#    - Deadline: Until the next meeting.
#
# 6. **Project Manager**:
#    - Task: Ensure the project remains on track and manage project-related activities.
#    - Deadline: Until the next meeting.
#
# 7. **User Interface Designer**:
#    - Task: Define the requirements for the user interface and brainstorm ways to realize the user needs and aspirations.
#    - Deadline: Until the next meeting.
#
# 8. **David & Craig**:
#    - Task: Produce a prototype remote control using play dough.
#    - Deadline: Until the next meeting.
#
# 9. **Andrew**:
#    - Task: Conduct a product evaluation.
#    - Deadline: Until the next meeting.
#
# These tasks are to be completed before the next scheduled meeting, which will allow for further discussion and progress updates.
# Question:What follow-up actions and plans are required for the next meeting?
# Answer:Based on the provided contexts, the follow-up actions and plans required for the next meeting can be summarized as follows:
#
# 1. **David (ID)**:
#    - Assess the limitations imposed by costs and determine what functionalities can be provided within the financial constraints.
#
# 2. **Andrew (ME)**:
#    - Develop a marketing strategy for the product, focusing on how to market it to different countries and identifying key selling points.
#
# 3. **Craig (UID)**:
#    - Create a technical specification for the product, detailing the necessary technical requirements and features.
#
# 4. **Aavid and another team member**:
#    - Prepare a mock-up of the control interface to visualize design changes and functionalities.
#
# 5. **Laura**:
#    - Compile and distribute the minutes of the previous meeting, ensuring all team members are informed of discussions and decisions made.
#
# 6. **Prototype Development**:
#    - David and Craig are tasked with producing a prototype remote control using play dough to explore design concepts and functionality.
#
# 7. **Product Evaluation**:
#    - Andrew will conduct a product evaluation to assess its viability and market readiness.
#
# These actions aim to clarify roles, address financial constraints, and ensure that all team members are aligned on their responsibilities before the next meeting.

# %%
from src.utils.generate import Generation 
from src.utils import utils
file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
prompt_config = utils.load_config(file_config["llm_env"]["prompting_file"])
generate = Generation(prompt_config)

# %%
from src.utils.llm_models import get_llm_model
import os
from dotenv import load_dotenv
load_dotenv()
config = {
    'openai_api_key': os.getenv("OPENAI_API_KEY"),
    'llm_choice': 'OpenAI', # Ollama
    'model_choice': 'gpt-4o-mini', # gpt-4o
    'parameters': {
        'temperature': 0.2,
        'top_p': 0.95,
        'max_retries': 2,
    },
}
llm = get_llm_model(
    chatmodel=config['llm_choice'], 
    model_name=config['model_choice'], 
    param=config['parameters'], 
)

# %%
from langchain_core.tracers.context import tracing_v2_enabled

with tracing_v2_enabled(project_name="generate_rag_multi_input_agenda"):
    agenda = generate.generate_rag_multi_input_agenda(llm=llm, qa_text=qa_text)
agenda
# Out:
# {'text': '**Meeting Agenda: Product Development Update**  \n\n1. **Introductions and Meeting Overview (5 minutes)**  \n  + **Overview of Meeting Purpose (2 minutes)**  \n    + Finalization of design prototype and alignment on key features.  \n    + Review of cost constraints and implications for design decisions.  \n  + **Team Introductions (3 minutes)**  \n    + Brief introductions of team members and their roles.  \n    + Overview of project objectives and current status.  \n\n2. **Project Updates (10 minutes)**  \n  + **Status Reports (5 minutes)**  \n    + Team members provide updates on their assigned tasks and significant developments.  \n    + Highlight any challenges faced and solutions proposed.  \n  + **Review of Previous Action Items (5 minutes)**  \n    + Discuss pending action items and clarify roles and responsibilities.  \n    + Address any outstanding issues from the last meeting.  \n\n3. **Discussion Topics (10 minutes)**  \n  + **Key Design Decisions (5 minutes)**  \n    + Discuss final decisions on product shape, materials, and functionality features.  \n    + Evaluate implications of decisions on market positioning and user experience.  \n  + **Team Dynamics and Communication (5 minutes)**  \n    + Address communication challenges and propose solutions for improved collaboration.  \n    + Discuss the effectiveness of current meeting structures and potential adjustments.  \n\n4. **Next Steps and Action Planning (5 minutes)**  \n  + **Task Assignments (3 minutes)**  \n    + Clearly assign tasks to team members with deadlines for the next meeting.  \n    + Ensure everyone understands their responsibilities moving forward.  \n  + **Follow-Up Plan (2 minutes)**  \n    + Outline the plan for the next meeting and any required follow-up actions.  \n\n5. **Open Questions and Closing (5 minutes)**  \n  + **Open Floor for Questions (3 minutes)**  \n    + Allow team members to raise any additional questions or concerns.  \n  + **Wrap-Up (2 minutes)**  \n    + Summarize key points discussed and confirm understanding.  \n    + Thank participants for their contributions.  \n\n**Total Time:** 35 minutes  ',
#  '__run': {'run_id': UUID('75dab4a7-484d-4d96-a6b2-12e8c2617acf')}}

# %%
print(agenda['text'])
# Out:
# **Meeting Agenda: Product Development Update**
#
# 1. **Introductions and Meeting Purpose (5 minutes)**
#   + **Overview of Meeting Objectives (2 minutes)**
#     + Finalization of design prototype and alignment on design elements.
#     + Review of cost constraints and implications for product features.
#   + **Team Introductions (3 minutes)**
#     + Each member introduces themselves and their role in the project.
#
# 2. **Project Updates (10 minutes)**
#   + **Status Reports on Assigned Tasks (5 minutes)**
#     + Team members provide updates on their assigned tasks and any significant developments.
#     + Highlight challenges faced and solutions proposed.
#   + **Review of Previous Action Items (5 minutes)**
#     + Discuss the status of pending action items and clarify roles and responsibilities.
#     + Address any challenges encountered since the last meeting.
#
# 3. **Discussion Topics (10 minutes)**
#   + **Product Design and Functionality (5 minutes)**
#     + Discuss the finalized design elements, including shape, materials, and features.
#     + Evaluate the essential functionalities and their alignment with budget constraints.
#   + **Market Positioning and Strategy (5 minutes)**
#     + Review target demographics and discuss marketing strategies for international markets.
#     + Address the implications of pricing strategy on product positioning.
#
# 4. **Decision-Making (5 minutes)**
#   + **Key Decisions Review (3 minutes)**
#     + Confirm decisions regarding design, features, and roles for team members.
#     + Ensure clarity on the implications of these decisions for the project.
#   + **Next Steps (2 minutes)**
#     + Outline immediate next steps for each team member and assign responsibilities.
#
# 5. **Action Items (5 minutes)**
#   + **Task Assignments (3 minutes)**
#     + Clearly assign tasks to team members with deadlines for completion.
#     + Ensure everyone understands their responsibilities moving forward.
#   + **Follow-Up Plan (2 minutes)**
#     + Discuss the plan for the next meeting and any required follow-up actions.
#
# 6. **Open Questions and Closing (5 minutes)**
#   + **Open Floor for Questions (3 minutes)**
#     + Allow team members to raise any additional questions or concerns.
#   + **Wrap-Up (2 minutes)**
#     + Summarize key points discussed and confirm understanding among team members.
#
# **Total Time:** 40 minutes

# %% [markdown]
# # Create 'Rag' Agenda from 67 meetings

# %%
from src.utils.generate import Generation 
from src.utils import utils
from src.utils.llm_models import get_llm_model
import os
from dotenv import load_dotenv
load_dotenv()
file_config = utils.load_config("src/config/file_config.yml")
model_config = utils.load_config(file_config["llm_env"]["model_config_file"])
prompt_config = utils.load_config(file_config["llm_env"]["prompting_file"])
generate = Generation(prompt_config)
config = {
    'openai_api_key': os.getenv("OPENAI_API_KEY"),
    'llm_choice': 'OpenAI', # Ollama
    'model_choice': 'gpt-4o-mini', # gpt-4o
    'parameters': {
        'temperature': 0.2,
        'top_p': 0.95,
        'max_retries': 2,
    },
}
llm = get_llm_model(
    chatmodel=config['llm_choice'], 
    model_name=config['model_choice'], 
    param=config['parameters'], 
)

# %%
# load qa_by_rag
import json
def load_qa_from_file(file, root:str = "/datadrive/CuongHV/project/DATA/mm_agenda_generation_research_output/qa_by_rag"):
    with open(f'{root}/{file}', 'r') as f:
        data = json.load(f)
    lines = [f'Question:{q}\nAnswer:{a}' for q,a in data['qa'].items()]
    qa_text = '\n'.join(lines)
    return qa_text

# %%
from langchain_core.tracers.context import tracing_v2_enabled
from tqdm import tqdm
root = "/datadrive/CuongHV/project/DATA/mm_agenda_generation_research_output/qa_by_rag"
for file in tqdm(os.listdir(root)):
    qa_text = load_qa_from_file(file)
    with tracing_v2_enabled(project_name="generate_rag_multi_input_agenda"):
        agenda = generate.generate_rag_multi_input_agenda(llm=llm, qa_text=qa_text)
    data = {
        'qa_text': qa_text,
        'agenda': agenda['text'],
    }
    with open(f'/datadrive/CuongHV/project/DATA/mm_agenda_generation_research_output/generate_rag_multi_input_agenda/{file}', 'a', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
# Out:
# 100%|██████████| 67/67 [12:08<00:00, 10.88s/it]
